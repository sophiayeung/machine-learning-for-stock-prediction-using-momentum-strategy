# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import datetime

import keras
from keras.models import Sequential
from keras.layers import Dense,InputLayer, Dropout
from keras.callbacks import EarlyStopping
from tcn import TCN,tcn_full_summary
from sklearn.metrics import accuracy_score


import numpy as np
import tensorflow as tf
from scikeras.wrappers import KerasClassifier
import keras_tuner

# %% [markdown]
# # Global Model

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self,hp):
        model = Sequential()
        model.add(InputLayer(input_shape=(240,1 )))
        hp_units = hp.Choice('units', values=[32,64,128])
        kernel_size = hp.Choice('kernel_size', values=[2, 4, 8,16])
        model.add(TCN(nb_filters=hp_units,kernel_size=kernel_size, name='dense_0'))
        model.add(Dropout(hp.Choice('dropout_rate',values =[0.5])))
        model.add(Dense(1, activation='sigmoid'))
        hp_lr = hp.Choice('learning_rate', values=[1e-6, 1e-7, 1e-8])
        hp_optimizer = hp.Choice('optimizer', values=['sgd', 'rmsprop', 'adam',"adamax"])
        if hp_optimizer == 'sgd':
            optimizer = keras.optimizers.SGD(learning_rate=hp_lr)
        elif hp_optimizer == 'rmsprop':
            optimizer = keras.optimizers.RMSprop(learning_rate=hp_lr)
        elif hp_optimizer == 'adam':
            optimizer = keras.optimizers.Adam(learning_rate=hp_lr)
        elif hp_optimizer == 'adamax':
            optimizer = keras.optimizers.Adamax(learning_rate=hp_lr)
        else:
            raise ValueError("Invalid optimizer choice")

        model.compile(
            optimizer = optimizer
            ,loss=keras.losses.BinaryCrossentropy()
            , metrics=['accuracy'])
        return model


    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size=hp.Choice("batch_size", [16, 32, 64,128]),
                **kwargs,
            )

# %%
tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy', #overwrite=True,
            max_trials=10, directory='tcn', seed=100)
print(tuner.search_space_summary())
# Out:
# Reloading Tuner from tcn/untitled_project/tuner0.json
# Search space summary
# Default search space size: 6
# units (Choice)
# {'default': 32, 'conditions': [], 'values': [32, 64, 128], 'ordered': True}
# kernel_size (Choice)
# {'default': 2, 'conditions': [], 'values': [2, 4, 8, 16], 'ordered': True}
# dropout_rate (Choice)
# {'default': 0.5, 'conditions': [], 'values': [0.5], 'ordered': True}
# learning_rate (Choice)
# {'default': 1e-06, 'conditions': [], 'values': [1e-06, 1e-07, 1e-08], 'ordered': True}
# optimizer (Choice)
# {'default': 'sgd', 'conditions': [], 'values': ['sgd', 'rmsprop', 'adam', 'adamax'], 'ordered': False}
# batch_size (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64, 128], 'ordered': True}
# None

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = []

for i in range(5):
    # read the data
    data_path ='/home/RDC/yeungwin/H:/yeungwin/DAX/data/'
    train = pd.read_csv(data_path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
    test = pd.read_csv(data_path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()

    train.columns = label
    test.columns = label

    train_label = train.iloc[:, timesteps]
    train_data = train.iloc[:, :timesteps]
    test_label = test.iloc[:,timesteps]
    test_data = test.iloc[:, :timesteps]
    
    
     # reshape input
    #  data: (samples, timesteps, features)
    x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
    x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
    # label: (samples, target)
    y_train = np.array(train_label).reshape((len(train_label), num_classes))
    y_test = np.array(test_label).reshape((len(test_label), num_classes))
        
    print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)
    
    print("-------------------------------------------------------------------------------------------------------")
    print("Training the model for Training Set " + str(i) + " from " +
    datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
    print("-------------------------------------------------------------------------------------------------------")
        
        
    if i==0:
        tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy', #overwrite=True,
            max_trials=10, directory='tcn', seed=100)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10, restore_best_weights=False)
        tuner.search(x_train,y_train, epochs =1000, validation_split=0.2, callbacks=[early_stop])

        # save the best model
        hypermodel = MyHyperModel()
        best_hp = tuner.get_best_hyperparameters()[0]
        print(tuner.get_best_hyperparameters()[0].get_config()["values"])

        best_model = hypermodel.build(best_hp)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 10, restore_best_weights=False)
        result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])

    else:
        load_path = '/home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5'
        print('Model restore from ' + load_path)
        cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                     save_weights_only=True,
                                                     verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                        patience = 10)

        result = best_model.fit(
                x_train, 
                y_train, 
                epochs = 1000, 
                validation_split=0.2,
                verbose =1,
                callbacks=[cp_callback, early_stop]        
            ) 
        
            
        
    save_path = '/home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5'
    best_model.save_weights(save_path)
    print("Model saved to " + save_path)
    print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        
    ##make prediction
    pred_ff_test = best_model.predict(x_test)
    #pred = pred_ff_test.tolist()
    pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
    output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                    'Date': test['target_date'], 'Sector': test['sector'], })
    accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
    print('Overall Accuracy for test set:'+ str(accuracy))
    output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_prediction/tcn_prediction_period_'+str(i)+'.csv')
    print('Prediction for period ' + str(i) + ' successfully saved.')
# Out:
# (14717, 240, 1)
# (14717, 1)
# (7149, 240, 1)
# (7149, 1)
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 0 from 2024-02-06 20:38:59
# -------------------------------------------------------------------------------------------------------
# Reloading Tuner from tcn/untitled_project/tuner0.json
# {'units': 128, 'kernel_size': 8, 'dropout_rate': 0.5, 'learning_rate': 1e-06, 'optimizer': 'sgd', 'batch_size': 128}
# Epoch 1/1000
# 368/368 [==============================] - 99s 264ms/step - loss: 13.7285 - accuracy: 0.5068 - val_loss: 7.9111 - val_accuracy: 0.4976
# Epoch 2/1000
# 368/368 [==============================] - 87s 235ms/step - loss: 8.8090 - accuracy: 0.5011 - val_loss: 3.7715 - val_accuracy: 0.5024
# Epoch 3/1000
# 368/368 [==============================] - 93s 252ms/step - loss: 7.7675 - accuracy: 0.4938 - val_loss: 2.8909 - val_accuracy: 0.5207
# Epoch 4/1000
# 368/368 [==============================] - 85s 232ms/step - loss: 7.3199 - accuracy: 0.5034 - val_loss: 2.6905 - val_accuracy: 0.5180
# Epoch 5/1000
# 368/368 [==============================] - 88s 239ms/step - loss: 7.0341 - accuracy: 0.4986 - val_loss: 2.5538 - val_accuracy: 0.5190
# Epoch 6/1000
# 368/368 [==============================] - 97s 262ms/step - loss: 6.7424 - accuracy: 0.4900 - val_loss: 2.4927 - val_accuracy: 0.5187
# Epoch 7/1000
# 368/368 [==============================] - 96s 261ms/step - loss: 6.4681 - accuracy: 0.4989 - val_loss: 2.4278 - val_accuracy: 0.5190
# Epoch 8/1000
# 368/368 [==============================] - 96s 262ms/step - loss: 6.1576 - accuracy: 0.5039 - val_loss: 2.3592 - val_accuracy: 0.5211
# Epoch 9/1000
# 368/368 [==============================] - 103s 280ms/step - loss: 5.9922 - accuracy: 0.5002 - val_loss: 2.3054 - val_accuracy: 0.5194
# Epoch 10/1000
# 368/368 [==============================] - 85s 232ms/step - loss: 5.7646 - accuracy: 0.4984 - val_loss: 2.2590 - val_accuracy: 0.5156
# Epoch 11/1000
# 368/368 [==============================] - 83s 225ms/step - loss: 5.7931 - accuracy: 0.4962 - val_loss: 2.2232 - val_accuracy: 0.5173
# Epoch 12/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 5.6302 - accuracy: 0.5011 - val_loss: 2.1759 - val_accuracy: 0.5180
# Epoch 13/1000
# 368/368 [==============================] - 95s 257ms/step - loss: 5.4311 - accuracy: 0.4968 - val_loss: 2.1359 - val_accuracy: 0.5163
# Epoch 14/1000
# 368/368 [==============================] - 93s 253ms/step - loss: 5.1761 - accuracy: 0.4977 - val_loss: 2.1041 - val_accuracy: 0.5160
# Epoch 15/1000
# 368/368 [==============================] - 94s 255ms/step - loss: 5.1045 - accuracy: 0.4978 - val_loss: 2.0701 - val_accuracy: 0.5139
# Epoch 16/1000
# 368/368 [==============================] - 99s 269ms/step - loss: 4.8455 - accuracy: 0.5017 - val_loss: 2.0409 - val_accuracy: 0.5143
# Epoch 17/1000
# 368/368 [==============================] - 110s 299ms/step - loss: 4.8442 - accuracy: 0.4982 - val_loss: 2.0111 - val_accuracy: 0.5153
# Epoch 18/1000
# 368/368 [==============================] - 94s 255ms/step - loss: 4.8976 - accuracy: 0.4923 - val_loss: 1.9904 - val_accuracy: 0.5112
# Epoch 19/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 4.6576 - accuracy: 0.5017 - val_loss: 1.9602 - val_accuracy: 0.5132
# Epoch 20/1000
# 368/368 [==============================] - 82s 223ms/step - loss: 4.7037 - accuracy: 0.4899 - val_loss: 1.9337 - val_accuracy: 0.5132
# Epoch 21/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 4.5432 - accuracy: 0.4989 - val_loss: 1.9112 - val_accuracy: 0.5143
# Epoch 22/1000
# 368/368 [==============================] - 94s 255ms/step - loss: 4.4607 - accuracy: 0.4974 - val_loss: 1.9027 - val_accuracy: 0.5143
# Epoch 23/1000
# 368/368 [==============================] - 92s 250ms/step - loss: 4.3648 - accuracy: 0.4968 - val_loss: 1.8808 - val_accuracy: 0.5163
# Epoch 24/1000
# 368/368 [==============================] - 100s 273ms/step - loss: 4.2154 - accuracy: 0.5021 - val_loss: 1.8544 - val_accuracy: 0.5153
# Epoch 25/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 4.1432 - accuracy: 0.4989 - val_loss: 1.8251 - val_accuracy: 0.5139
# Epoch 26/1000
# 368/368 [==============================] - 106s 289ms/step - loss: 4.2123 - accuracy: 0.4970 - val_loss: 1.8062 - val_accuracy: 0.5136
# Epoch 27/1000
# 368/368 [==============================] - 77s 209ms/step - loss: 4.0829 - accuracy: 0.5025 - val_loss: 1.7898 - val_accuracy: 0.5146
# Epoch 28/1000
# 368/368 [==============================] - 91s 246ms/step - loss: 3.9809 - accuracy: 0.5028 - val_loss: 1.7795 - val_accuracy: 0.5143
# Epoch 29/1000
# 368/368 [==============================] - 102s 278ms/step - loss: 4.0140 - accuracy: 0.4997 - val_loss: 1.7586 - val_accuracy: 0.5119
# Epoch 30/1000
# 368/368 [==============================] - 93s 252ms/step - loss: 3.8928 - accuracy: 0.5034 - val_loss: 1.7457 - val_accuracy: 0.5122
# Epoch 31/1000
# 368/368 [==============================] - 94s 255ms/step - loss: 3.8790 - accuracy: 0.4984 - val_loss: 1.7260 - val_accuracy: 0.5126
# Epoch 32/1000
# 368/368 [==============================] - 98s 267ms/step - loss: 3.8258 - accuracy: 0.5047 - val_loss: 1.7108 - val_accuracy: 0.5115
# Epoch 33/1000
# 368/368 [==============================] - 102s 277ms/step - loss: 3.8130 - accuracy: 0.4972 - val_loss: 1.6950 - val_accuracy: 0.5102
# Epoch 34/1000
# 368/368 [==============================] - 111s 301ms/step - loss: 3.7273 - accuracy: 0.5028 - val_loss: 1.6752 - val_accuracy: 0.5122
# Epoch 35/1000
# 368/368 [==============================] - 104s 284ms/step - loss: 3.7695 - accuracy: 0.4963 - val_loss: 1.6653 - val_accuracy: 0.5126
# Epoch 36/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 3.5871 - accuracy: 0.5011 - val_loss: 1.6537 - val_accuracy: 0.5112
# Epoch 37/1000
# 368/368 [==============================] - 88s 238ms/step - loss: 3.5964 - accuracy: 0.4978 - val_loss: 1.6399 - val_accuracy: 0.5129
# Epoch 38/1000
# 368/368 [==============================] - 99s 268ms/step - loss: 3.6735 - accuracy: 0.4924 - val_loss: 1.6293 - val_accuracy: 0.5122
# Epoch 39/1000
# 368/368 [==============================] - 103s 280ms/step - loss: 3.4881 - accuracy: 0.5052 - val_loss: 1.6095 - val_accuracy: 0.5099
# Epoch 40/1000
# 368/368 [==============================] - 95s 258ms/step - loss: 3.5191 - accuracy: 0.4992 - val_loss: 1.5971 - val_accuracy: 0.5088
# Epoch 41/1000
# 368/368 [==============================] - 102s 276ms/step - loss: 3.4692 - accuracy: 0.4976 - val_loss: 1.5883 - val_accuracy: 0.5088
# Epoch 42/1000
# 368/368 [==============================] - 108s 293ms/step - loss: 3.3998 - accuracy: 0.5068 - val_loss: 1.5743 - val_accuracy: 0.5085
# Epoch 43/1000
# 368/368 [==============================] - 96s 262ms/step - loss: 3.4166 - accuracy: 0.5001 - val_loss: 1.5669 - val_accuracy: 0.5085
# Epoch 44/1000
# 368/368 [==============================] - 114s 309ms/step - loss: 3.3838 - accuracy: 0.5042 - val_loss: 1.5547 - val_accuracy: 0.5085
# Epoch 45/1000
# 368/368 [==============================] - 107s 292ms/step - loss: 3.3411 - accuracy: 0.5034 - val_loss: 1.5465 - val_accuracy: 0.5095
# Epoch 46/1000
# 368/368 [==============================] - 106s 287ms/step - loss: 3.3197 - accuracy: 0.4996 - val_loss: 1.5392 - val_accuracy: 0.5109
# Epoch 47/1000
# 368/368 [==============================] - 94s 254ms/step - loss: 3.3094 - accuracy: 0.4927 - val_loss: 1.5257 - val_accuracy: 0.5129
# Epoch 48/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 3.2527 - accuracy: 0.4932 - val_loss: 1.5170 - val_accuracy: 0.5132
# Epoch 49/1000
# 368/368 [==============================] - 86s 234ms/step - loss: 3.2783 - accuracy: 0.4921 - val_loss: 1.5073 - val_accuracy: 0.5139
# Epoch 50/1000
# 368/368 [==============================] - 97s 263ms/step - loss: 3.2084 - accuracy: 0.4958 - val_loss: 1.5003 - val_accuracy: 0.5149
# Epoch 51/1000
# 368/368 [==============================] - 98s 267ms/step - loss: 3.1689 - accuracy: 0.4984 - val_loss: 1.4906 - val_accuracy: 0.5132
# Epoch 52/1000
# 368/368 [==============================] - 97s 263ms/step - loss: 3.1657 - accuracy: 0.5014 - val_loss: 1.4802 - val_accuracy: 0.5122
# Epoch 53/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 3.1595 - accuracy: 0.4995 - val_loss: 1.4701 - val_accuracy: 0.5122
# Epoch 54/1000
# 368/368 [==============================] - 110s 300ms/step - loss: 3.0973 - accuracy: 0.4979 - val_loss: 1.4636 - val_accuracy: 0.5122
# Epoch 55/1000
# 368/368 [==============================] - 108s 292ms/step - loss: 3.0694 - accuracy: 0.4956 - val_loss: 1.4587 - val_accuracy: 0.5122
# Epoch 56/1000
# 368/368 [==============================] - 101s 274ms/step - loss: 3.0206 - accuracy: 0.4933 - val_loss: 1.4498 - val_accuracy: 0.5129
# Epoch 57/1000
# 368/368 [==============================] - 104s 283ms/step - loss: 3.0059 - accuracy: 0.4974 - val_loss: 1.4427 - val_accuracy: 0.5129
# Epoch 58/1000
# 368/368 [==============================] - 102s 278ms/step - loss: 2.9945 - accuracy: 0.4927 - val_loss: 1.4329 - val_accuracy: 0.5119
# Epoch 59/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 2.9807 - accuracy: 0.4948 - val_loss: 1.4229 - val_accuracy: 0.5109
# Epoch 60/1000
# 368/368 [==============================] - 101s 273ms/step - loss: 3.0000 - accuracy: 0.4970 - val_loss: 1.4167 - val_accuracy: 0.5115
# Epoch 61/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 2.8631 - accuracy: 0.5007 - val_loss: 1.4100 - val_accuracy: 0.5119
# Epoch 62/1000
# 368/368 [==============================] - 81s 220ms/step - loss: 2.8942 - accuracy: 0.4993 - val_loss: 1.4043 - val_accuracy: 0.5119
# Epoch 63/1000
# 368/368 [==============================] - 103s 281ms/step - loss: 2.8917 - accuracy: 0.4997 - val_loss: 1.3957 - val_accuracy: 0.5119
# Epoch 64/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 2.8613 - accuracy: 0.4980 - val_loss: 1.3902 - val_accuracy: 0.5122
# Epoch 65/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 2.7944 - accuracy: 0.5113 - val_loss: 1.3831 - val_accuracy: 0.5136
# Epoch 66/1000
# 368/368 [==============================] - 107s 291ms/step - loss: 2.7432 - accuracy: 0.5056 - val_loss: 1.3750 - val_accuracy: 0.5126
# Epoch 67/1000
# 368/368 [==============================] - 97s 262ms/step - loss: 2.7424 - accuracy: 0.5012 - val_loss: 1.3702 - val_accuracy: 0.5146
# Epoch 68/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 2.7669 - accuracy: 0.5045 - val_loss: 1.3654 - val_accuracy: 0.5129
# Epoch 69/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 2.7603 - accuracy: 0.4953 - val_loss: 1.3614 - val_accuracy: 0.5102
# Epoch 70/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 2.7589 - accuracy: 0.5015 - val_loss: 1.3552 - val_accuracy: 0.5099
# Epoch 71/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 2.7418 - accuracy: 0.4962 - val_loss: 1.3504 - val_accuracy: 0.5112
# Epoch 72/1000
# 368/368 [==============================] - 111s 301ms/step - loss: 2.7115 - accuracy: 0.5016 - val_loss: 1.3426 - val_accuracy: 0.5119
# Epoch 73/1000
# 368/368 [==============================] - 106s 289ms/step - loss: 2.6597 - accuracy: 0.5028 - val_loss: 1.3356 - val_accuracy: 0.5132
# Epoch 74/1000
# 368/368 [==============================] - 106s 287ms/step - loss: 2.6709 - accuracy: 0.5020 - val_loss: 1.3307 - val_accuracy: 0.5146
# Epoch 75/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 2.6940 - accuracy: 0.4981 - val_loss: 1.3260 - val_accuracy: 0.5146
# Epoch 76/1000
# 368/368 [==============================] - 113s 308ms/step - loss: 2.6135 - accuracy: 0.5002 - val_loss: 1.3204 - val_accuracy: 0.5143
# Epoch 77/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 2.6789 - accuracy: 0.4995 - val_loss: 1.3172 - val_accuracy: 0.5173
# Epoch 78/1000
# 368/368 [==============================] - 92s 251ms/step - loss: 2.6086 - accuracy: 0.5039 - val_loss: 1.3133 - val_accuracy: 0.5170
# Epoch 79/1000
# 368/368 [==============================] - 113s 306ms/step - loss: 2.5839 - accuracy: 0.4952 - val_loss: 1.3066 - val_accuracy: 0.5163
# Epoch 80/1000
# 368/368 [==============================] - 112s 303ms/step - loss: 2.6243 - accuracy: 0.4990 - val_loss: 1.3002 - val_accuracy: 0.5170
# Epoch 81/1000
# 368/368 [==============================] - 110s 299ms/step - loss: 2.5532 - accuracy: 0.5045 - val_loss: 1.2962 - val_accuracy: 0.5180
# Epoch 82/1000
# 368/368 [==============================] - 96s 261ms/step - loss: 2.5438 - accuracy: 0.5049 - val_loss: 1.2922 - val_accuracy: 0.5173
# Epoch 83/1000
# 368/368 [==============================] - 93s 253ms/step - loss: 2.5548 - accuracy: 0.4981 - val_loss: 1.2870 - val_accuracy: 0.5170
# Epoch 84/1000
# 368/368 [==============================] - 93s 253ms/step - loss: 2.5166 - accuracy: 0.5006 - val_loss: 1.2831 - val_accuracy: 0.5173
# Epoch 85/1000
# 368/368 [==============================] - 102s 277ms/step - loss: 2.4972 - accuracy: 0.5062 - val_loss: 1.2789 - val_accuracy: 0.5166
# Epoch 86/1000
# 368/368 [==============================] - 109s 296ms/step - loss: 2.5109 - accuracy: 0.4994 - val_loss: 1.2739 - val_accuracy: 0.5163
# Epoch 87/1000
# 368/368 [==============================] - 114s 309ms/step - loss: 2.4964 - accuracy: 0.5008 - val_loss: 1.2693 - val_accuracy: 0.5166
# Epoch 88/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 2.5042 - accuracy: 0.5004 - val_loss: 1.2645 - val_accuracy: 0.5170
# Epoch 89/1000
# 368/368 [==============================] - 99s 269ms/step - loss: 2.4656 - accuracy: 0.5058 - val_loss: 1.2596 - val_accuracy: 0.5160
# Epoch 90/1000
# 368/368 [==============================] - 91s 247ms/step - loss: 2.4575 - accuracy: 0.4990 - val_loss: 1.2550 - val_accuracy: 0.5156
# Epoch 91/1000
# 368/368 [==============================] - 104s 284ms/step - loss: 2.4579 - accuracy: 0.4953 - val_loss: 1.2507 - val_accuracy: 0.5160
# Epoch 92/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 2.4324 - accuracy: 0.5032 - val_loss: 1.2470 - val_accuracy: 0.5166
# Epoch 93/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 2.4454 - accuracy: 0.4990 - val_loss: 1.2429 - val_accuracy: 0.5163
# Epoch 94/1000
# 368/368 [==============================] - 107s 290ms/step - loss: 2.3714 - accuracy: 0.5033 - val_loss: 1.2388 - val_accuracy: 0.5170
# Epoch 95/1000
# 368/368 [==============================] - 103s 281ms/step - loss: 2.4123 - accuracy: 0.4977 - val_loss: 1.2358 - val_accuracy: 0.5173
# Epoch 96/1000
# 368/368 [==============================] - 98s 265ms/step - loss: 2.3684 - accuracy: 0.5049 - val_loss: 1.2309 - val_accuracy: 0.5197
# Epoch 97/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 2.3924 - accuracy: 0.4997 - val_loss: 1.2270 - val_accuracy: 0.5197
# Epoch 98/1000
# 368/368 [==============================] - 99s 269ms/step - loss: 2.3993 - accuracy: 0.5023 - val_loss: 1.2232 - val_accuracy: 0.5207
# Epoch 99/1000
# 368/368 [==============================] - 97s 265ms/step - loss: 2.3613 - accuracy: 0.4977 - val_loss: 1.2189 - val_accuracy: 0.5214
# Epoch 100/1000
# 368/368 [==============================] - 97s 265ms/step - loss: 2.3519 - accuracy: 0.5039 - val_loss: 1.2150 - val_accuracy: 0.5221
# Epoch 101/1000
# 368/368 [==============================] - 93s 252ms/step - loss: 2.3204 - accuracy: 0.5009 - val_loss: 1.2119 - val_accuracy: 0.5211
# Epoch 102/1000
# 368/368 [==============================] - 103s 281ms/step - loss: 2.3122 - accuracy: 0.5033 - val_loss: 1.2085 - val_accuracy: 0.5217
# Epoch 103/1000
# 368/368 [==============================] - 94s 257ms/step - loss: 2.3058 - accuracy: 0.5070 - val_loss: 1.2047 - val_accuracy: 0.5231
# Epoch 104/1000
# 368/368 [==============================] - 90s 245ms/step - loss: 2.3380 - accuracy: 0.4963 - val_loss: 1.2014 - val_accuracy: 0.5224
# Epoch 105/1000
# 368/368 [==============================] - 106s 288ms/step - loss: 2.3032 - accuracy: 0.5031 - val_loss: 1.1977 - val_accuracy: 0.5238
# Epoch 106/1000
# 368/368 [==============================] - 87s 236ms/step - loss: 2.2320 - accuracy: 0.5040 - val_loss: 1.1939 - val_accuracy: 0.5248
# Epoch 107/1000
# 368/368 [==============================] - 83s 227ms/step - loss: 2.2372 - accuracy: 0.5068 - val_loss: 1.1907 - val_accuracy: 0.5245
# Epoch 108/1000
# 368/368 [==============================] - 96s 261ms/step - loss: 2.2286 - accuracy: 0.5092 - val_loss: 1.1872 - val_accuracy: 0.5248
# Epoch 109/1000
# 368/368 [==============================] - 90s 244ms/step - loss: 2.2709 - accuracy: 0.4998 - val_loss: 1.1840 - val_accuracy: 0.5245
# Epoch 110/1000
# 368/368 [==============================] - 97s 263ms/step - loss: 2.2125 - accuracy: 0.5043 - val_loss: 1.1813 - val_accuracy: 0.5248
# Epoch 111/1000
# 368/368 [==============================] - 102s 278ms/step - loss: 2.2296 - accuracy: 0.5003 - val_loss: 1.1775 - val_accuracy: 0.5245
# Epoch 112/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 2.1806 - accuracy: 0.5023 - val_loss: 1.1750 - val_accuracy: 0.5251
# Epoch 113/1000
# 368/368 [==============================] - 104s 283ms/step - loss: 2.2049 - accuracy: 0.5071 - val_loss: 1.1720 - val_accuracy: 0.5255
# Epoch 114/1000
# 368/368 [==============================] - 91s 246ms/step - loss: 2.1820 - accuracy: 0.5024 - val_loss: 1.1676 - val_accuracy: 0.5245
# Epoch 115/1000
# 368/368 [==============================] - 86s 233ms/step - loss: 2.1378 - accuracy: 0.5026 - val_loss: 1.1652 - val_accuracy: 0.5255
# Epoch 116/1000
# 368/368 [==============================] - 101s 275ms/step - loss: 2.1491 - accuracy: 0.5081 - val_loss: 1.1616 - val_accuracy: 0.5231
# Epoch 117/1000
# 368/368 [==============================] - 97s 263ms/step - loss: 2.1468 - accuracy: 0.5037 - val_loss: 1.1585 - val_accuracy: 0.5221
# Epoch 118/1000
# 368/368 [==============================] - 88s 239ms/step - loss: 2.1522 - accuracy: 0.5101 - val_loss: 1.1561 - val_accuracy: 0.5228
# Epoch 119/1000
# 368/368 [==============================] - 93s 254ms/step - loss: 2.1782 - accuracy: 0.4943 - val_loss: 1.1539 - val_accuracy: 0.5231
# Epoch 120/1000
# 368/368 [==============================] - 96s 260ms/step - loss: 2.1164 - accuracy: 0.5052 - val_loss: 1.1516 - val_accuracy: 0.5224
# Epoch 121/1000
# 368/368 [==============================] - 99s 269ms/step - loss: 2.1509 - accuracy: 0.5005 - val_loss: 1.1497 - val_accuracy: 0.5234
# Epoch 122/1000
# 368/368 [==============================] - 90s 244ms/step - loss: 2.1185 - accuracy: 0.4998 - val_loss: 1.1463 - val_accuracy: 0.5211
# Epoch 123/1000
# 368/368 [==============================] - 100s 273ms/step - loss: 2.0935 - accuracy: 0.5035 - val_loss: 1.1436 - val_accuracy: 0.5214
# Epoch 124/1000
# 368/368 [==============================] - 91s 247ms/step - loss: 2.1144 - accuracy: 0.5007 - val_loss: 1.1409 - val_accuracy: 0.5211
# Epoch 125/1000
# 368/368 [==============================] - 87s 236ms/step - loss: 2.1596 - accuracy: 0.5000 - val_loss: 1.1384 - val_accuracy: 0.5211
# Epoch 126/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 2.0993 - accuracy: 0.5042 - val_loss: 1.1354 - val_accuracy: 0.5207
# Epoch 127/1000
# 368/368 [==============================] - 91s 247ms/step - loss: 2.1524 - accuracy: 0.4935 - val_loss: 1.1323 - val_accuracy: 0.5200
# Epoch 128/1000
# 368/368 [==============================] - 95s 257ms/step - loss: 2.1016 - accuracy: 0.5009 - val_loss: 1.1302 - val_accuracy: 0.5214
# Epoch 129/1000
# 368/368 [==============================] - 93s 252ms/step - loss: 2.0657 - accuracy: 0.5038 - val_loss: 1.1281 - val_accuracy: 0.5204
# Epoch 130/1000
# 368/368 [==============================] - 83s 226ms/step - loss: 2.0721 - accuracy: 0.5035 - val_loss: 1.1262 - val_accuracy: 0.5204
# Epoch 131/1000
# 368/368 [==============================] - 115s 311ms/step - loss: 2.0842 - accuracy: 0.4989 - val_loss: 1.1237 - val_accuracy: 0.5217
# Epoch 132/1000
# 368/368 [==============================] - 95s 258ms/step - loss: 2.0082 - accuracy: 0.5051 - val_loss: 1.1211 - val_accuracy: 0.5224
# Epoch 133/1000
# 368/368 [==============================] - 101s 274ms/step - loss: 2.0312 - accuracy: 0.5053 - val_loss: 1.1191 - val_accuracy: 0.5228
# Epoch 134/1000
# 368/368 [==============================] - 98s 267ms/step - loss: 2.0228 - accuracy: 0.5085 - val_loss: 1.1158 - val_accuracy: 0.5217
# Epoch 135/1000
# 368/368 [==============================] - 89s 241ms/step - loss: 2.0562 - accuracy: 0.5075 - val_loss: 1.1129 - val_accuracy: 0.5217
# Epoch 136/1000
# 368/368 [==============================] - 104s 282ms/step - loss: 2.0129 - accuracy: 0.5006 - val_loss: 1.1112 - val_accuracy: 0.5217
# Epoch 137/1000
# 368/368 [==============================] - 91s 248ms/step - loss: 2.0283 - accuracy: 0.4930 - val_loss: 1.1099 - val_accuracy: 0.5221
# Epoch 138/1000
# 368/368 [==============================] - 92s 250ms/step - loss: 1.9847 - accuracy: 0.4996 - val_loss: 1.1071 - val_accuracy: 0.5221
# Epoch 139/1000
# 368/368 [==============================] - 83s 226ms/step - loss: 1.9841 - accuracy: 0.5035 - val_loss: 1.1042 - val_accuracy: 0.5217
# Epoch 140/1000
# 368/368 [==============================] - 92s 251ms/step - loss: 1.9835 - accuracy: 0.5046 - val_loss: 1.1016 - val_accuracy: 0.5217
# Epoch 141/1000
# 368/368 [==============================] - 96s 261ms/step - loss: 2.0208 - accuracy: 0.5046 - val_loss: 1.0989 - val_accuracy: 0.5204
# Epoch 142/1000
# 368/368 [==============================] - 92s 249ms/step - loss: 1.9972 - accuracy: 0.4957 - val_loss: 1.0965 - val_accuracy: 0.5204
# Epoch 143/1000
# 368/368 [==============================] - 107s 292ms/step - loss: 1.9246 - accuracy: 0.5131 - val_loss: 1.0949 - val_accuracy: 0.5197
# Epoch 144/1000
# 368/368 [==============================] - 81s 220ms/step - loss: 1.9326 - accuracy: 0.5041 - val_loss: 1.0930 - val_accuracy: 0.5200
# Epoch 145/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 1.9303 - accuracy: 0.5036 - val_loss: 1.0917 - val_accuracy: 0.5204
# Epoch 146/1000
# 368/368 [==============================] - 91s 248ms/step - loss: 1.9531 - accuracy: 0.5021 - val_loss: 1.0889 - val_accuracy: 0.5187
# Epoch 147/1000
# 368/368 [==============================] - 81s 220ms/step - loss: 1.9021 - accuracy: 0.5067 - val_loss: 1.0865 - val_accuracy: 0.5187
# Epoch 148/1000
# 368/368 [==============================] - 81s 221ms/step - loss: 1.9388 - accuracy: 0.5064 - val_loss: 1.0837 - val_accuracy: 0.5190
# Epoch 149/1000
# 368/368 [==============================] - 79s 214ms/step - loss: 1.9524 - accuracy: 0.4987 - val_loss: 1.0812 - val_accuracy: 0.5197
# Epoch 150/1000
# 368/368 [==============================] - 83s 227ms/step - loss: 1.9117 - accuracy: 0.5065 - val_loss: 1.0790 - val_accuracy: 0.5187
# Epoch 151/1000
# 368/368 [==============================] - 95s 258ms/step - loss: 1.9051 - accuracy: 0.5066 - val_loss: 1.0773 - val_accuracy: 0.5204
# Epoch 152/1000
# 368/368 [==============================] - 104s 283ms/step - loss: 1.8848 - accuracy: 0.5088 - val_loss: 1.0754 - val_accuracy: 0.5197
# Epoch 153/1000
# 368/368 [==============================] - 104s 283ms/step - loss: 1.9186 - accuracy: 0.5044 - val_loss: 1.0735 - val_accuracy: 0.5180
# Epoch 154/1000
# 368/368 [==============================] - 93s 253ms/step - loss: 1.8830 - accuracy: 0.5054 - val_loss: 1.0713 - val_accuracy: 0.5180
# Epoch 155/1000
# 368/368 [==============================] - 91s 248ms/step - loss: 1.9045 - accuracy: 0.4976 - val_loss: 1.0690 - val_accuracy: 0.5183
# Epoch 156/1000
# 368/368 [==============================] - 101s 274ms/step - loss: 1.9011 - accuracy: 0.5045 - val_loss: 1.0673 - val_accuracy: 0.5180
# Epoch 157/1000
# 368/368 [==============================] - 96s 262ms/step - loss: 1.9067 - accuracy: 0.5012 - val_loss: 1.0652 - val_accuracy: 0.5173
# Epoch 158/1000
# 368/368 [==============================] - 105s 285ms/step - loss: 1.9047 - accuracy: 0.4993 - val_loss: 1.0637 - val_accuracy: 0.5160
# Epoch 159/1000
# 368/368 [==============================] - 88s 240ms/step - loss: 1.8517 - accuracy: 0.5023 - val_loss: 1.0620 - val_accuracy: 0.5153
# Epoch 160/1000
# 368/368 [==============================] - 92s 250ms/step - loss: 1.8511 - accuracy: 0.4983 - val_loss: 1.0597 - val_accuracy: 0.5156
# Epoch 161/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 1.8591 - accuracy: 0.5079 - val_loss: 1.0582 - val_accuracy: 0.5160
# Epoch 162/1000
# 368/368 [==============================] - 93s 254ms/step - loss: 1.8496 - accuracy: 0.5041 - val_loss: 1.0569 - val_accuracy: 0.5149
# Epoch 163/1000
# 368/368 [==============================] - 102s 278ms/step - loss: 1.8520 - accuracy: 0.5016 - val_loss: 1.0550 - val_accuracy: 0.5153
# Epoch 164/1000
# 368/368 [==============================] - 84s 229ms/step - loss: 1.8469 - accuracy: 0.5041 - val_loss: 1.0535 - val_accuracy: 0.5149
# Epoch 165/1000
# 368/368 [==============================] - 101s 274ms/step - loss: 1.8656 - accuracy: 0.5022 - val_loss: 1.0523 - val_accuracy: 0.5146
# Epoch 166/1000
# 368/368 [==============================] - 96s 261ms/step - loss: 1.8055 - accuracy: 0.5013 - val_loss: 1.0497 - val_accuracy: 0.5160
# Epoch 167/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.8328 - accuracy: 0.5076 - val_loss: 1.0479 - val_accuracy: 0.5163
# Epoch 168/1000
# 368/368 [==============================] - 98s 267ms/step - loss: 1.8228 - accuracy: 0.5071 - val_loss: 1.0464 - val_accuracy: 0.5156
# Epoch 169/1000
# 368/368 [==============================] - 101s 274ms/step - loss: 1.8360 - accuracy: 0.5049 - val_loss: 1.0444 - val_accuracy: 0.5163
# Epoch 170/1000
# 368/368 [==============================] - 101s 273ms/step - loss: 1.8033 - accuracy: 0.5040 - val_loss: 1.0423 - val_accuracy: 0.5160
# Epoch 171/1000
# 368/368 [==============================] - 99s 269ms/step - loss: 1.8539 - accuracy: 0.5027 - val_loss: 1.0407 - val_accuracy: 0.5163
# Epoch 172/1000
# 368/368 [==============================] - 93s 253ms/step - loss: 1.8229 - accuracy: 0.5003 - val_loss: 1.0395 - val_accuracy: 0.5170
# Epoch 173/1000
# 368/368 [==============================] - 87s 237ms/step - loss: 1.8025 - accuracy: 0.5121 - val_loss: 1.0375 - val_accuracy: 0.5163
# Epoch 174/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.7937 - accuracy: 0.5063 - val_loss: 1.0359 - val_accuracy: 0.5163
# Epoch 175/1000
# 368/368 [==============================] - 96s 261ms/step - loss: 1.7843 - accuracy: 0.5008 - val_loss: 1.0341 - val_accuracy: 0.5163
# Epoch 176/1000
# 368/368 [==============================] - 94s 257ms/step - loss: 1.7836 - accuracy: 0.5086 - val_loss: 1.0320 - val_accuracy: 0.5173
# Epoch 177/1000
# 368/368 [==============================] - 97s 263ms/step - loss: 1.7917 - accuracy: 0.5028 - val_loss: 1.0305 - val_accuracy: 0.5180
# Epoch 178/1000
# 368/368 [==============================] - 105s 286ms/step - loss: 1.7678 - accuracy: 0.5070 - val_loss: 1.0293 - val_accuracy: 0.5166
# Epoch 179/1000
# 368/368 [==============================] - 78s 212ms/step - loss: 1.7618 - accuracy: 0.5011 - val_loss: 1.0280 - val_accuracy: 0.5166
# Epoch 180/1000
# 368/368 [==============================] - 88s 241ms/step - loss: 1.7826 - accuracy: 0.5101 - val_loss: 1.0266 - val_accuracy: 0.5170
# Epoch 181/1000
# 368/368 [==============================] - 104s 283ms/step - loss: 1.7186 - accuracy: 0.5077 - val_loss: 1.0254 - val_accuracy: 0.5170
# Epoch 182/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.7460 - accuracy: 0.5123 - val_loss: 1.0231 - val_accuracy: 0.5180
# Epoch 183/1000
# 368/368 [==============================] - 104s 281ms/step - loss: 1.7580 - accuracy: 0.5014 - val_loss: 1.0217 - val_accuracy: 0.5170
# Epoch 184/1000
# 368/368 [==============================] - 94s 257ms/step - loss: 1.7882 - accuracy: 0.5012 - val_loss: 1.0202 - val_accuracy: 0.5177
# Epoch 185/1000
# 368/368 [==============================] - 93s 254ms/step - loss: 1.6947 - accuracy: 0.5135 - val_loss: 1.0183 - val_accuracy: 0.5173
# Epoch 186/1000
# 368/368 [==============================] - 109s 296ms/step - loss: 1.7489 - accuracy: 0.5011 - val_loss: 1.0167 - val_accuracy: 0.5180
# Epoch 187/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 1.7266 - accuracy: 0.5099 - val_loss: 1.0150 - val_accuracy: 0.5177
# Epoch 188/1000
# 368/368 [==============================] - 93s 252ms/step - loss: 1.7377 - accuracy: 0.5080 - val_loss: 1.0137 - val_accuracy: 0.5180
# Epoch 189/1000
# 368/368 [==============================] - 93s 253ms/step - loss: 1.6906 - accuracy: 0.5102 - val_loss: 1.0124 - val_accuracy: 0.5173
# Epoch 190/1000
# 368/368 [==============================] - 85s 230ms/step - loss: 1.6981 - accuracy: 0.5063 - val_loss: 1.0109 - val_accuracy: 0.5177
# Epoch 191/1000
# 368/368 [==============================] - 86s 233ms/step - loss: 1.6718 - accuracy: 0.5098 - val_loss: 1.0095 - val_accuracy: 0.5177
# Epoch 192/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.7425 - accuracy: 0.5049 - val_loss: 1.0086 - val_accuracy: 0.5177
# Epoch 193/1000
# 368/368 [==============================] - 95s 260ms/step - loss: 1.6973 - accuracy: 0.5071 - val_loss: 1.0071 - val_accuracy: 0.5173
# Epoch 194/1000
# 368/368 [==============================] - 102s 277ms/step - loss: 1.6903 - accuracy: 0.5040 - val_loss: 1.0050 - val_accuracy: 0.5156
# Epoch 195/1000
# 368/368 [==============================] - 90s 245ms/step - loss: 1.7148 - accuracy: 0.5039 - val_loss: 1.0037 - val_accuracy: 0.5153
# Epoch 196/1000
# 368/368 [==============================] - 101s 275ms/step - loss: 1.7102 - accuracy: 0.5092 - val_loss: 1.0024 - val_accuracy: 0.5160
# Epoch 197/1000
# 368/368 [==============================] - 82s 222ms/step - loss: 1.6958 - accuracy: 0.5062 - val_loss: 1.0013 - val_accuracy: 0.5166
# Epoch 198/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.6800 - accuracy: 0.5028 - val_loss: 0.9998 - val_accuracy: 0.5153
# Epoch 199/1000
# 368/368 [==============================] - 94s 256ms/step - loss: 1.6530 - accuracy: 0.5072 - val_loss: 0.9984 - val_accuracy: 0.5146
# Epoch 200/1000
# 368/368 [==============================] - 93s 252ms/step - loss: 1.6782 - accuracy: 0.5066 - val_loss: 0.9971 - val_accuracy: 0.5153
# Epoch 201/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.6564 - accuracy: 0.5073 - val_loss: 0.9960 - val_accuracy: 0.5166
# Epoch 202/1000
# 368/368 [==============================] - 101s 275ms/step - loss: 1.6799 - accuracy: 0.5046 - val_loss: 0.9944 - val_accuracy: 0.5163
# Epoch 203/1000
# 368/368 [==============================] - 96s 262ms/step - loss: 1.6872 - accuracy: 0.5003 - val_loss: 0.9933 - val_accuracy: 0.5173
# Epoch 204/1000
# 368/368 [==============================] - 94s 255ms/step - loss: 1.6586 - accuracy: 0.5088 - val_loss: 0.9920 - val_accuracy: 0.5180
# Epoch 205/1000
# 368/368 [==============================] - 111s 303ms/step - loss: 1.6447 - accuracy: 0.5084 - val_loss: 0.9906 - val_accuracy: 0.5180
# Epoch 206/1000
# 368/368 [==============================] - 88s 240ms/step - loss: 1.6220 - accuracy: 0.5056 - val_loss: 0.9898 - val_accuracy: 0.5194
# Epoch 207/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 1.6236 - accuracy: 0.5117 - val_loss: 0.9879 - val_accuracy: 0.5166
# Epoch 208/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.6512 - accuracy: 0.5035 - val_loss: 0.9867 - val_accuracy: 0.5166
# Epoch 209/1000
# 368/368 [==============================] - 95s 258ms/step - loss: 1.6450 - accuracy: 0.5039 - val_loss: 0.9857 - val_accuracy: 0.5177
# Epoch 210/1000
# 368/368 [==============================] - 89s 241ms/step - loss: 1.6182 - accuracy: 0.5099 - val_loss: 0.9844 - val_accuracy: 0.5163
# Epoch 211/1000
# 368/368 [==============================] - 97s 262ms/step - loss: 1.6293 - accuracy: 0.5118 - val_loss: 0.9835 - val_accuracy: 0.5180
# Epoch 212/1000
# 368/368 [==============================] - 106s 289ms/step - loss: 1.6370 - accuracy: 0.5051 - val_loss: 0.9821 - val_accuracy: 0.5183
# Epoch 213/1000
# 368/368 [==============================] - 106s 288ms/step - loss: 1.6173 - accuracy: 0.5068 - val_loss: 0.9811 - val_accuracy: 0.5187
# Epoch 214/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.6087 - accuracy: 0.5164 - val_loss: 0.9796 - val_accuracy: 0.5190
# Epoch 215/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 1.6374 - accuracy: 0.5039 - val_loss: 0.9787 - val_accuracy: 0.5194
# Epoch 216/1000
# 368/368 [==============================] - 110s 299ms/step - loss: 1.6326 - accuracy: 0.5014 - val_loss: 0.9779 - val_accuracy: 0.5190
# Epoch 217/1000
# 368/368 [==============================] - 97s 263ms/step - loss: 1.6572 - accuracy: 0.5022 - val_loss: 0.9766 - val_accuracy: 0.5197
# Epoch 218/1000
# 368/368 [==============================] - 108s 294ms/step - loss: 1.5967 - accuracy: 0.5081 - val_loss: 0.9751 - val_accuracy: 0.5197
# Epoch 219/1000
# 368/368 [==============================] - 105s 285ms/step - loss: 1.5907 - accuracy: 0.5044 - val_loss: 0.9738 - val_accuracy: 0.5200
# Epoch 220/1000
# 368/368 [==============================] - 109s 296ms/step - loss: 1.6131 - accuracy: 0.5056 - val_loss: 0.9728 - val_accuracy: 0.5194
# Epoch 221/1000
# 368/368 [==============================] - 96s 260ms/step - loss: 1.6000 - accuracy: 0.5047 - val_loss: 0.9716 - val_accuracy: 0.5190
# Epoch 222/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.5706 - accuracy: 0.5114 - val_loss: 0.9706 - val_accuracy: 0.5190
# Epoch 223/1000
# 368/368 [==============================] - 97s 265ms/step - loss: 1.5897 - accuracy: 0.5064 - val_loss: 0.9696 - val_accuracy: 0.5187
# Epoch 224/1000
# 368/368 [==============================] - 107s 290ms/step - loss: 1.5775 - accuracy: 0.5135 - val_loss: 0.9686 - val_accuracy: 0.5177
# Epoch 225/1000
# 368/368 [==============================] - 98s 267ms/step - loss: 1.5788 - accuracy: 0.5072 - val_loss: 0.9673 - val_accuracy: 0.5177
# Epoch 226/1000
# 368/368 [==============================] - 91s 247ms/step - loss: 1.5939 - accuracy: 0.5020 - val_loss: 0.9662 - val_accuracy: 0.5177
# Epoch 227/1000
# 368/368 [==============================] - 98s 265ms/step - loss: 1.5779 - accuracy: 0.5095 - val_loss: 0.9653 - val_accuracy: 0.5170
# Epoch 228/1000
# 368/368 [==============================] - 111s 301ms/step - loss: 1.6026 - accuracy: 0.5068 - val_loss: 0.9638 - val_accuracy: 0.5173
# Epoch 229/1000
# 368/368 [==============================] - 89s 242ms/step - loss: 1.5419 - accuracy: 0.5154 - val_loss: 0.9629 - val_accuracy: 0.5173
# Epoch 230/1000
# 368/368 [==============================] - 99s 269ms/step - loss: 1.5872 - accuracy: 0.5026 - val_loss: 0.9618 - val_accuracy: 0.5177
# Epoch 231/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 1.5822 - accuracy: 0.5022 - val_loss: 0.9615 - val_accuracy: 0.5187
# Epoch 232/1000
# 368/368 [==============================] - 99s 268ms/step - loss: 1.5319 - accuracy: 0.5096 - val_loss: 0.9602 - val_accuracy: 0.5177
# Epoch 233/1000
# 368/368 [==============================] - 95s 258ms/step - loss: 1.5426 - accuracy: 0.5089 - val_loss: 0.9588 - val_accuracy: 0.5200
# Epoch 234/1000
# 368/368 [==============================] - 95s 258ms/step - loss: 1.5370 - accuracy: 0.5112 - val_loss: 0.9580 - val_accuracy: 0.5194
# Epoch 235/1000
# 368/368 [==============================] - 93s 252ms/step - loss: 1.5505 - accuracy: 0.5069 - val_loss: 0.9569 - val_accuracy: 0.5190
# Epoch 236/1000
# 368/368 [==============================] - 102s 276ms/step - loss: 1.5289 - accuracy: 0.5084 - val_loss: 0.9561 - val_accuracy: 0.5190
# Epoch 237/1000
# 368/368 [==============================] - 83s 227ms/step - loss: 1.5609 - accuracy: 0.4982 - val_loss: 0.9550 - val_accuracy: 0.5207
# Epoch 238/1000
# 368/368 [==============================] - 98s 268ms/step - loss: 1.5339 - accuracy: 0.5021 - val_loss: 0.9543 - val_accuracy: 0.5197
# Epoch 239/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.5413 - accuracy: 0.5062 - val_loss: 0.9533 - val_accuracy: 0.5197
# Epoch 240/1000
# 368/368 [==============================] - 97s 265ms/step - loss: 1.5304 - accuracy: 0.5093 - val_loss: 0.9521 - val_accuracy: 0.5214
# Epoch 241/1000
# 368/368 [==============================] - 105s 285ms/step - loss: 1.5427 - accuracy: 0.5118 - val_loss: 0.9515 - val_accuracy: 0.5211
# Epoch 242/1000
# 368/368 [==============================] - 102s 277ms/step - loss: 1.5222 - accuracy: 0.5077 - val_loss: 0.9503 - val_accuracy: 0.5214
# Epoch 243/1000
# 368/368 [==============================] - 107s 290ms/step - loss: 1.5141 - accuracy: 0.5106 - val_loss: 0.9495 - val_accuracy: 0.5211
# Epoch 244/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 1.5340 - accuracy: 0.5072 - val_loss: 0.9482 - val_accuracy: 0.5214
# Epoch 245/1000
# 368/368 [==============================] - 103s 281ms/step - loss: 1.5296 - accuracy: 0.5129 - val_loss: 0.9473 - val_accuracy: 0.5214
# Epoch 246/1000
# 368/368 [==============================] - 101s 276ms/step - loss: 1.5214 - accuracy: 0.5078 - val_loss: 0.9464 - val_accuracy: 0.5217
# Epoch 247/1000
# 368/368 [==============================] - 104s 284ms/step - loss: 1.5020 - accuracy: 0.5088 - val_loss: 0.9455 - val_accuracy: 0.5207
# Epoch 248/1000
# 368/368 [==============================] - 99s 269ms/step - loss: 1.5298 - accuracy: 0.5107 - val_loss: 0.9443 - val_accuracy: 0.5207
# Epoch 249/1000
# 368/368 [==============================] - 92s 251ms/step - loss: 1.5309 - accuracy: 0.5010 - val_loss: 0.9434 - val_accuracy: 0.5204
# Epoch 250/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 1.5104 - accuracy: 0.5063 - val_loss: 0.9430 - val_accuracy: 0.5190
# Epoch 251/1000
# 368/368 [==============================] - 103s 281ms/step - loss: 1.4986 - accuracy: 0.5110 - val_loss: 0.9418 - val_accuracy: 0.5200
# Epoch 252/1000
# 368/368 [==============================] - 101s 274ms/step - loss: 1.5186 - accuracy: 0.4980 - val_loss: 0.9412 - val_accuracy: 0.5183
# Epoch 253/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 1.4944 - accuracy: 0.5079 - val_loss: 0.9400 - val_accuracy: 0.5200
# Epoch 254/1000
# 368/368 [==============================] - 103s 280ms/step - loss: 1.4673 - accuracy: 0.5142 - val_loss: 0.9389 - val_accuracy: 0.5207
# Epoch 255/1000
# 368/368 [==============================] - 94s 255ms/step - loss: 1.4906 - accuracy: 0.5093 - val_loss: 0.9379 - val_accuracy: 0.5207
# Epoch 256/1000
# 368/368 [==============================] - 95s 258ms/step - loss: 1.5004 - accuracy: 0.5097 - val_loss: 0.9368 - val_accuracy: 0.5214
# Epoch 257/1000
# 368/368 [==============================] - 99s 268ms/step - loss: 1.4683 - accuracy: 0.5114 - val_loss: 0.9361 - val_accuracy: 0.5207
# Epoch 258/1000
# 368/368 [==============================] - 102s 278ms/step - loss: 1.4854 - accuracy: 0.5076 - val_loss: 0.9352 - val_accuracy: 0.5214
# Epoch 259/1000
# 368/368 [==============================] - 106s 288ms/step - loss: 1.4867 - accuracy: 0.5057 - val_loss: 0.9344 - val_accuracy: 0.5211
# Epoch 260/1000
# 368/368 [==============================] - 105s 287ms/step - loss: 1.4760 - accuracy: 0.5081 - val_loss: 0.9334 - val_accuracy: 0.5214
# Epoch 261/1000
# 368/368 [==============================] - 104s 282ms/step - loss: 1.4750 - accuracy: 0.5016 - val_loss: 0.9327 - val_accuracy: 0.5211
# Epoch 262/1000
# 368/368 [==============================] - 103s 280ms/step - loss: 1.4629 - accuracy: 0.5088 - val_loss: 0.9318 - val_accuracy: 0.5207
# Epoch 263/1000
# 368/368 [==============================] - 101s 275ms/step - loss: 1.4922 - accuracy: 0.5063 - val_loss: 0.9311 - val_accuracy: 0.5200
# Epoch 264/1000
# 368/368 [==============================] - 88s 239ms/step - loss: 1.4521 - accuracy: 0.5095 - val_loss: 0.9305 - val_accuracy: 0.5200
# Epoch 265/1000
# 368/368 [==============================] - 88s 238ms/step - loss: 1.4679 - accuracy: 0.5162 - val_loss: 0.9298 - val_accuracy: 0.5190
# Epoch 266/1000
# 368/368 [==============================] - 104s 283ms/step - loss: 1.4759 - accuracy: 0.5060 - val_loss: 0.9290 - val_accuracy: 0.5183
# Epoch 267/1000
# 368/368 [==============================] - 107s 290ms/step - loss: 1.4335 - accuracy: 0.5165 - val_loss: 0.9279 - val_accuracy: 0.5190
# Epoch 268/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 1.4478 - accuracy: 0.5060 - val_loss: 0.9272 - val_accuracy: 0.5190
# Epoch 269/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.4771 - accuracy: 0.5063 - val_loss: 0.9266 - val_accuracy: 0.5180
# Epoch 270/1000
# 368/368 [==============================] - 104s 284ms/step - loss: 1.4852 - accuracy: 0.5022 - val_loss: 0.9257 - val_accuracy: 0.5173
# Epoch 271/1000
# 368/368 [==============================] - 103s 281ms/step - loss: 1.4425 - accuracy: 0.5086 - val_loss: 0.9248 - val_accuracy: 0.5183
# Epoch 272/1000
# 368/368 [==============================] - 102s 278ms/step - loss: 1.4622 - accuracy: 0.5048 - val_loss: 0.9240 - val_accuracy: 0.5190
# Epoch 273/1000
# 368/368 [==============================] - 103s 280ms/step - loss: 1.4701 - accuracy: 0.5068 - val_loss: 0.9231 - val_accuracy: 0.5187
# Epoch 274/1000
# 368/368 [==============================] - 108s 293ms/step - loss: 1.4173 - accuracy: 0.5086 - val_loss: 0.9222 - val_accuracy: 0.5177
# Epoch 275/1000
# 368/368 [==============================] - 106s 287ms/step - loss: 1.4535 - accuracy: 0.5047 - val_loss: 0.9212 - val_accuracy: 0.5190
# Epoch 276/1000
# 368/368 [==============================] - 96s 260ms/step - loss: 1.4504 - accuracy: 0.5017 - val_loss: 0.9206 - val_accuracy: 0.5190
# Epoch 277/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 1.4484 - accuracy: 0.5130 - val_loss: 0.9198 - val_accuracy: 0.5194
# Epoch 278/1000
# 368/368 [==============================] - 84s 228ms/step - loss: 1.4401 - accuracy: 0.5105 - val_loss: 0.9193 - val_accuracy: 0.5177
# Epoch 279/1000
# 368/368 [==============================] - 92s 251ms/step - loss: 1.4125 - accuracy: 0.5125 - val_loss: 0.9185 - val_accuracy: 0.5170
# Epoch 280/1000
# 368/368 [==============================] - 98s 265ms/step - loss: 1.4266 - accuracy: 0.5058 - val_loss: 0.9176 - val_accuracy: 0.5177
# Epoch 281/1000
# 368/368 [==============================] - 96s 260ms/step - loss: 1.4174 - accuracy: 0.5083 - val_loss: 0.9169 - val_accuracy: 0.5173
# Epoch 282/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.4225 - accuracy: 0.5098 - val_loss: 0.9161 - val_accuracy: 0.5177
# Epoch 283/1000
# 368/368 [==============================] - 103s 280ms/step - loss: 1.4190 - accuracy: 0.5158 - val_loss: 0.9152 - val_accuracy: 0.5183
# Epoch 284/1000
# 368/368 [==============================] - 105s 286ms/step - loss: 1.4142 - accuracy: 0.5203 - val_loss: 0.9145 - val_accuracy: 0.5173
# Epoch 285/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.4082 - accuracy: 0.5114 - val_loss: 0.9140 - val_accuracy: 0.5180
# Epoch 286/1000
# 368/368 [==============================] - 94s 255ms/step - loss: 1.4148 - accuracy: 0.5093 - val_loss: 0.9132 - val_accuracy: 0.5173
# Epoch 287/1000
# 368/368 [==============================] - 102s 278ms/step - loss: 1.4339 - accuracy: 0.5088 - val_loss: 0.9124 - val_accuracy: 0.5173
# Epoch 288/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.3816 - accuracy: 0.5146 - val_loss: 0.9114 - val_accuracy: 0.5187
# Epoch 289/1000
# 368/368 [==============================] - 99s 270ms/step - loss: 1.4146 - accuracy: 0.5085 - val_loss: 0.9107 - val_accuracy: 0.5190
# Epoch 290/1000
# 368/368 [==============================] - 110s 299ms/step - loss: 1.4217 - accuracy: 0.5069 - val_loss: 0.9099 - val_accuracy: 0.5187
# Epoch 291/1000
# 368/368 [==============================] - 109s 296ms/step - loss: 1.3887 - accuracy: 0.5137 - val_loss: 0.9090 - val_accuracy: 0.5190
# Epoch 292/1000
# 368/368 [==============================] - 103s 281ms/step - loss: 1.4090 - accuracy: 0.5090 - val_loss: 0.9082 - val_accuracy: 0.5190
# Epoch 293/1000
# 368/368 [==============================] - 108s 293ms/step - loss: 1.4094 - accuracy: 0.5093 - val_loss: 0.9074 - val_accuracy: 0.5194
# Epoch 294/1000
# 368/368 [==============================] - 110s 299ms/step - loss: 1.4222 - accuracy: 0.5013 - val_loss: 0.9066 - val_accuracy: 0.5190
# Epoch 295/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 1.3885 - accuracy: 0.5130 - val_loss: 0.9059 - val_accuracy: 0.5187
# Epoch 296/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 1.4010 - accuracy: 0.5108 - val_loss: 0.9054 - val_accuracy: 0.5187
# Epoch 297/1000
# 368/368 [==============================] - 106s 289ms/step - loss: 1.4097 - accuracy: 0.5091 - val_loss: 0.9046 - val_accuracy: 0.5194
# Epoch 298/1000
# 368/368 [==============================] - 100s 272ms/step - loss: 1.3885 - accuracy: 0.5091 - val_loss: 0.9040 - val_accuracy: 0.5190
# Epoch 299/1000
# 368/368 [==============================] - 99s 268ms/step - loss: 1.3480 - accuracy: 0.5207 - val_loss: 0.9034 - val_accuracy: 0.5187
# Epoch 300/1000
# 368/368 [==============================] - 97s 263ms/step - loss: 1.3766 - accuracy: 0.5136 - val_loss: 0.9030 - val_accuracy: 0.5187
# Epoch 301/1000
# 368/368 [==============================] - 97s 262ms/step - loss: 1.3780 - accuracy: 0.5099 - val_loss: 0.9022 - val_accuracy: 0.5187
# Epoch 302/1000
# 368/368 [==============================] - 98s 265ms/step - loss: 1.3944 - accuracy: 0.5039 - val_loss: 0.9015 - val_accuracy: 0.5197
# Epoch 303/1000
# 368/368 [==============================] - 96s 261ms/step - loss: 1.3657 - accuracy: 0.5118 - val_loss: 0.9011 - val_accuracy: 0.5190
# Epoch 304/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 1.3845 - accuracy: 0.5096 - val_loss: 0.9003 - val_accuracy: 0.5187
# Epoch 305/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 1.3850 - accuracy: 0.5118 - val_loss: 0.8997 - val_accuracy: 0.5194
# Epoch 306/1000
# 368/368 [==============================] - 95s 259ms/step - loss: 1.3672 - accuracy: 0.5074 - val_loss: 0.8991 - val_accuracy: 0.5190
# Epoch 307/1000
# 368/368 [==============================] - 98s 266ms/step - loss: 1.3739 - accuracy: 0.5048 - val_loss: 0.8986 - val_accuracy: 0.5183
# Epoch 308/1000
# 368/368 [==============================] - 100s 271ms/step - loss: 1.3923 - accuracy: 0.5044 - val_loss: 0.8978 - val_accuracy: 0.5190
# Epoch 309/1000
# 368/368 [==============================] - 101s 274ms/step - loss: 1.3419 - accuracy: 0.5131 - val_loss: 0.8971 - val_accuracy: 0.5194
# Epoch 310/1000
# 368/368 [==============================] - 96s 260ms/step - loss: 1.3734 - accuracy: 0.5153 - val_loss: 0.8964 - val_accuracy: 0.5194
# Epoch 311/1000
# 368/368 [==============================] - 97s 264ms/step - loss: 1.3896 - accuracy: 0.4994 - val_loss: 0.8958 - val_accuracy: 0.5194
# Epoch 312/1000
# 368/368 [==============================] - 92s 250ms/step - loss: 1.3658 - accuracy: 0.5080 - val_loss: 0.8951 - val_accuracy: 0.5194
# Epoch 313/1000
# 368/368 [==============================] - 96s 262ms/step - loss: 1.3849 - accuracy: 0.5023 - val_loss: 0.8945 - val_accuracy: 0.5187
# Epoch 314/1000
# 368/368 [==============================] - 87s 237ms/step - loss: 1.3691 - accuracy: 0.5107 - val_loss: 0.8941 - val_accuracy: 0.5183
# Epoch 315/1000
# 368/368 [==============================] - 82s 224ms/step - loss: 1.3460 - accuracy: 0.5045 - val_loss: 0.8934 - val_accuracy: 0.5187
# Epoch 316/1000
# 368/368 [==============================] - 92s 250ms/step - loss: 1.3294 - accuracy: 0.5136 - val_loss: 0.8927 - val_accuracy: 0.5194
# Epoch 317/1000
# 368/368 [==============================] - 104s 283ms/step - loss: 1.3310 - accuracy: 0.5086 - val_loss: 0.8921 - val_accuracy: 0.5190
# Epoch 318/1000
# 368/368 [==============================] - 106s 288ms/step - loss: 1.3441 - accuracy: 0.5101 - val_loss: 0.8917 - val_accuracy: 0.5187
# Epoch 319/1000
# ...
# Epoch 980/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7275 - accuracy: 0.5160
# Epoch 980: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 69s 186ms/step - loss: 0.7275 - accuracy: 0.5160 - val_loss: 0.7067 - val_accuracy: 0.5131
# Epoch 981/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7229 - accuracy: 0.5240
# Epoch 981: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 69s 185ms/step - loss: 0.7229 - accuracy: 0.5240 - val_loss: 0.7067 - val_accuracy: 0.5131
# Epoch 982/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7237 - accuracy: 0.5194
# Epoch 982: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 72s 192ms/step - loss: 0.7237 - accuracy: 0.5194 - val_loss: 0.7067 - val_accuracy: 0.5134
# Epoch 983/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7256 - accuracy: 0.5122
# Epoch 983: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 72s 194ms/step - loss: 0.7256 - accuracy: 0.5122 - val_loss: 0.7067 - val_accuracy: 0.5131
# Epoch 984/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7224 - accuracy: 0.5169
# Epoch 984: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 69s 184ms/step - loss: 0.7224 - accuracy: 0.5169 - val_loss: 0.7067 - val_accuracy: 0.5131
# Epoch 985/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7235 - accuracy: 0.5169
# Epoch 985: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 183ms/step - loss: 0.7235 - accuracy: 0.5169 - val_loss: 0.7067 - val_accuracy: 0.5131
# Epoch 986/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7284 - accuracy: 0.5102
# Epoch 986: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 183ms/step - loss: 0.7284 - accuracy: 0.5102 - val_loss: 0.7066 - val_accuracy: 0.5127
# Epoch 987/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7181 - accuracy: 0.5280
# Epoch 987: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 182ms/step - loss: 0.7181 - accuracy: 0.5280 - val_loss: 0.7066 - val_accuracy: 0.5127
# Epoch 988/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7264 - accuracy: 0.5169
# Epoch 988: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 72s 193ms/step - loss: 0.7264 - accuracy: 0.5169 - val_loss: 0.7066 - val_accuracy: 0.5127
# Epoch 989/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7269 - accuracy: 0.5111
# Epoch 989: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 182ms/step - loss: 0.7269 - accuracy: 0.5111 - val_loss: 0.7066 - val_accuracy: 0.5127
# Epoch 990/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.5228
# Epoch 990: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 183ms/step - loss: 0.7225 - accuracy: 0.5228 - val_loss: 0.7066 - val_accuracy: 0.5117
# Epoch 991/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7219 - accuracy: 0.5164
# Epoch 991: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 79s 212ms/step - loss: 0.7219 - accuracy: 0.5164 - val_loss: 0.7066 - val_accuracy: 0.5124
# Epoch 992/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.5141
# Epoch 992: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 70s 188ms/step - loss: 0.7279 - accuracy: 0.5141 - val_loss: 0.7066 - val_accuracy: 0.5124
# Epoch 993/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7267 - accuracy: 0.5141
# Epoch 993: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 183ms/step - loss: 0.7267 - accuracy: 0.5141 - val_loss: 0.7066 - val_accuracy: 0.5121
# Epoch 994/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7264 - accuracy: 0.5105
# Epoch 994: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 183ms/step - loss: 0.7264 - accuracy: 0.5105 - val_loss: 0.7066 - val_accuracy: 0.5121
# Epoch 995/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7231 - accuracy: 0.5221
# Epoch 995: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 69s 184ms/step - loss: 0.7231 - accuracy: 0.5221 - val_loss: 0.7066 - val_accuracy: 0.5114
# Epoch 996/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7257 - accuracy: 0.5119
# Epoch 996: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 69s 184ms/step - loss: 0.7257 - accuracy: 0.5119 - val_loss: 0.7066 - val_accuracy: 0.5117
# Epoch 997/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7273 - accuracy: 0.5115
# Epoch 997: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 183ms/step - loss: 0.7273 - accuracy: 0.5115 - val_loss: 0.7065 - val_accuracy: 0.5117
# Epoch 998/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7260 - accuracy: 0.5123
# Epoch 998: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 68s 184ms/step - loss: 0.7260 - accuracy: 0.5123 - val_loss: 0.7065 - val_accuracy: 0.5097
# Epoch 999/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7264 - accuracy: 0.5125
# Epoch 999: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 69s 184ms/step - loss: 0.7264 - accuracy: 0.5125 - val_loss: 0.7065 - val_accuracy: 0.5111
# Epoch 1000/1000
# 373/373 [==============================] - ETA: 0s - loss: 0.7241 - accuracy: 0.5162
# Epoch 1000: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 373/373 [==============================] - 71s 192ms/step - loss: 0.7241 - accuracy: 0.5162 - val_loss: 0.7065 - val_accuracy: 0.5111
# Model saved to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# Training end: 2024-02-08 22:42:16
# 233/233 [==============================] - 16s 69ms/step
# Overall Accuracy for test set:0.5022824919441461
# Prediction for period 2 successfully saved.
# (15248, 240, 1)
# (15248, 1)
# (7058, 240, 1)
# (7058, 1)
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 3 from 2024-02-08 22:42:36
# -------------------------------------------------------------------------------------------------------
# Model restore from /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# Epoch 1/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7363 - accuracy: 0.5107
# Epoch 1: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 75s 196ms/step - loss: 0.7363 - accuracy: 0.5107 - val_loss: 0.7140 - val_accuracy: 0.5167
# Epoch 2/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7362 - accuracy: 0.5078
# Epoch 2: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 70s 184ms/step - loss: 0.7362 - accuracy: 0.5078 - val_loss: 0.7140 - val_accuracy: 0.5161
# Epoch 3/1000
# 381/382 [============================>.] - ETA: 0s - loss: 0.7318 - accuracy: 0.5135
# Epoch 3: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 70s 183ms/step - loss: 0.7319 - accuracy: 0.5134 - val_loss: 0.7141 - val_accuracy: 0.5157
# Epoch 4/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7392 - accuracy: 0.5017
# Epoch 4: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 70s 183ms/step - loss: 0.7392 - accuracy: 0.5017 - val_loss: 0.7140 - val_accuracy: 0.5161
# Epoch 5/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7372 - accuracy: 0.5121
# Epoch 5: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 70s 183ms/step - loss: 0.7372 - accuracy: 0.5121 - val_loss: 0.7140 - val_accuracy: 0.5157
# Epoch 6/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7356 - accuracy: 0.5056
# Epoch 6: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 70s 185ms/step - loss: 0.7356 - accuracy: 0.5056 - val_loss: 0.7141 - val_accuracy: 0.5157
# Epoch 7/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7369 - accuracy: 0.5034
# Epoch 7: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 70s 184ms/step - loss: 0.7369 - accuracy: 0.5034 - val_loss: 0.7141 - val_accuracy: 0.5154
# Epoch 8/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7330 - accuracy: 0.5138
# Epoch 8: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 70s 183ms/step - loss: 0.7330 - accuracy: 0.5138 - val_loss: 0.7141 - val_accuracy: 0.5151
# Epoch 9/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7364 - accuracy: 0.5079
# Epoch 9: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 71s 185ms/step - loss: 0.7364 - accuracy: 0.5079 - val_loss: 0.7141 - val_accuracy: 0.5154
# Epoch 10/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7333 - accuracy: 0.5105
# Epoch 10: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 71s 185ms/step - loss: 0.7333 - accuracy: 0.5105 - val_loss: 0.7141 - val_accuracy: 0.5154
# Epoch 11/1000
# 382/382 [==============================] - ETA: 0s - loss: 0.7369 - accuracy: 0.5068
# Epoch 11: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 382/382 [==============================] - 68s 178ms/step - loss: 0.7369 - accuracy: 0.5068 - val_loss: 0.7140 - val_accuracy: 0.5164
# Model saved to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# Training end: 2024-02-08 22:55:58
# 221/221 [==============================] - 16s 71ms/step
# Overall Accuracy for test set:0.5036837631056956
# Prediction for period 3 successfully saved.
# (14806, 240, 1)
# (14806, 1)
# (7175, 240, 1)
# (7175, 1)
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 4 from 2024-02-08 22:56:16
# -------------------------------------------------------------------------------------------------------
# Model restore from /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# Epoch 1/1000
# 371/371 [==============================] - ETA: 0s - loss: 0.7454 - accuracy: 0.4992
# Epoch 1: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 66s 178ms/step - loss: 0.7454 - accuracy: 0.4992 - val_loss: 0.7223 - val_accuracy: 0.5051
# Epoch 2/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7456 - accuracy: 0.5002
# Epoch 2: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 66s 178ms/step - loss: 0.7456 - accuracy: 0.5003 - val_loss: 0.7223 - val_accuracy: 0.5057
# Epoch 3/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7465 - accuracy: 0.5008
# Epoch 3: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 66s 177ms/step - loss: 0.7464 - accuracy: 0.5009 - val_loss: 0.7223 - val_accuracy: 0.5057
# Epoch 4/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7443 - accuracy: 0.5095
# Epoch 4: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 66s 177ms/step - loss: 0.7442 - accuracy: 0.5095 - val_loss: 0.7224 - val_accuracy: 0.5068
# Epoch 5/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7491 - accuracy: 0.4995
# Epoch 5: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 66s 177ms/step - loss: 0.7490 - accuracy: 0.4997 - val_loss: 0.7224 - val_accuracy: 0.5064
# Epoch 6/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7448 - accuracy: 0.5026
# Epoch 6: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 70s 188ms/step - loss: 0.7449 - accuracy: 0.5026 - val_loss: 0.7225 - val_accuracy: 0.5051
# Epoch 7/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7458 - accuracy: 0.5002
# Epoch 7: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 74s 201ms/step - loss: 0.7457 - accuracy: 0.5003 - val_loss: 0.7224 - val_accuracy: 0.5054
# Epoch 8/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7448 - accuracy: 0.4997
# Epoch 8: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 74s 200ms/step - loss: 0.7448 - accuracy: 0.4997 - val_loss: 0.7224 - val_accuracy: 0.5054
# Epoch 9/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7442 - accuracy: 0.5070
# Epoch 9: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 66s 178ms/step - loss: 0.7442 - accuracy: 0.5070 - val_loss: 0.7225 - val_accuracy: 0.5047
# Epoch 10/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7443 - accuracy: 0.5017
# Epoch 10: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 67s 179ms/step - loss: 0.7443 - accuracy: 0.5018 - val_loss: 0.7225 - val_accuracy: 0.5047
# Epoch 11/1000
# 370/371 [============================>.] - ETA: 0s - loss: 0.7516 - accuracy: 0.4924
# Epoch 11: saving model to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# 371/371 [==============================] - 66s 178ms/step - loss: 0.7516 - accuracy: 0.4924 - val_loss: 0.7225 - val_accuracy: 0.5054
# Model saved to /home/RDC/yeungwin/H:/yeungwin/DAX/7_TCN/tcn_model_weight/tcn_weight0.h5
# Training end: 2024-02-08 23:08:42
# 225/225 [==============================] - 16s 70ms/step
# Overall Accuracy for test set:0.5036933797909408
# Prediction for period 4 successfully saved.

# %%
print('Complete')
# Out:
# Complete
