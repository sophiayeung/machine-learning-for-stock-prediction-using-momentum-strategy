# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import datetime

import keras
from keras.models import Sequential
from keras.layers import Dense, InputLayer, LSTM, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
import keras_tuner
from keras import regularizers
# Out:
# 2024-03-13 21:32:07.931326: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-13 21:32:07.934043: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-13 21:32:07.980108: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 21:32:07.980129: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 21:32:07.980154: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-13 21:32:07.990136: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-13 21:32:07.990752: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 21:32:08.808617: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # 240 days data

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self,hp):
        model = Sequential()
        model.add(InputLayer(input_shape=(240,1 )))
        hp_units = hp.Choice('units', values=[32,64,128])
        hp_lr = hp.Choice('learning_rate', values=[1e-6,1e-7,1e-8])
        hp_regulariers = hp.Choice('regularies', values = ['l1','l2', 'None'])
        if hp_regulariers == 'l1':
            regularizers = keras.regularizers.L1(hp_lr)
        elif hp_regulariers == 'l2':
            regularizers = keras.regularizers.L2(hp_lr)
        elif hp_regulariers == 'None':
            regularizers = None
        
        model.add(LSTM(units=hp_units,kernel_regularizer=regularizers,name='dense_0'))
        model.add(Dropout(0.5))
        model.add(Dense(1, activation='sigmoid'))
        
        hp_optimizer = hp.Choice('optimizer', values=['sgd', 'rmsprop', 'adam',"adamax"])
        if hp_optimizer == 'sgd':
            optimizer = keras.optimizers.SGD(learning_rate=hp_lr)
        elif hp_optimizer == 'rmsprop':
            optimizer = keras.optimizers.RMSprop(learning_rate=hp_lr)
        elif hp_optimizer == 'adam':
            optimizer = keras.optimizers.Adam(learning_rate=hp_lr)
        elif hp_optimizer == 'adamax':
            optimizer = keras.optimizers.Adamax(learning_rate=hp_lr)
        else:
            raise ValueError("Invalid optimizer choice")

        model.compile(
            optimizer = optimizer
            ,loss=keras.losses.BinaryCrossentropy()
            , metrics=['accuracy'])
        return model


    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size=hp.Choice("batch_size", [16,32,64,128]),
                **kwargs,
            )

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = []


for i in range(5):
    # read the data
    path  = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
    train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
    test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()

    train.columns = label
    test.columns = label

    train_label = train.iloc[:, timesteps]
    train_data = train.iloc[:, :timesteps]
    test_label = test.iloc[:,timesteps]
    test_data = test.iloc[:, :timesteps]
    
    
     # reshape input
    #  data: (samples, timesteps, features)
    x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
    x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
    # label: (samples, target)
    y_train = np.array(train_label).reshape((len(train_label), num_classes))
    y_test = np.array(test_label).reshape((len(test_label), num_classes))
        
    print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)
    
    print("-------------------------------------------------------------------------------------------------------")
    print("Training the model for Training Set " + str(i) + " from " +
    datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
    print("-------------------------------------------------------------------------------------------------------")
        
    if i ==0:   
        tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy', #overwrite=True,
            max_trials=5, directory='lstm14', seed=999)
        #early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
        tuner.search(x_train,y_train, epochs =10, validation_split=0.2)

        # save the best model
        hypermodel = MyHyperModel()
        best_hp = tuner.get_best_hyperparameters()[0]
        best_model = hypermodel.build(best_hp)

        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
        result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])
        print(tuner.get_best_hyperparameters()[0].get_config()["values"])

    else: 
        load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5'
        print('Model restore from ' + load_path)
        cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                 save_weights_only=True,
                                                 verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 10)

        result = best_model.fit(
            x_train, 
            y_train, 
            epochs = 1000, 
            validation_split=0.2,
            verbose =1,
            callbacks=[cp_callback, early_stop]        
        ) 
            
    model_path ="/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5"    
    best_model.save_weights(model_path)
    print("Model saved to " + model_path)
    print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        
    ##make prediction
    pred_ff_test = best_model.predict(x_test)
    #pred = pred_ff_test.tolist()
    pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
    output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                    'Date': test['target_date'], 'Sector': test['sector'], })
    accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
    print('Overall Accuracy for test set:'+ str(accuracy))
    output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/pred14/lstm_prediction_period_'+str(i)+'.csv')
    print('Prediction for period ' + str(i) + ' successfully saved.')
# Out:
# Trial 5 Complete [02h 23m 45s]
# val_accuracy: 0.5054692029953003
#
# Best val_accuracy So Far: 0.5108060240745544
# Total elapsed time: 10h 45m 00s
# Epoch 1/1000
# 6137/6137 [==============================] - 491s 80ms/step - loss: 0.6934 - accuracy: 0.5016 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 2/1000
# 6137/6137 [==============================] - 496s 81ms/step - loss: 0.6933 - accuracy: 0.5026 - val_loss: 0.6931 - val_accuracy: 0.5059
# Epoch 3/1000
# 6137/6137 [==============================] - 484s 79ms/step - loss: 0.6934 - accuracy: 0.5036 - val_loss: 0.6931 - val_accuracy: 0.5073
# Epoch 4/1000
# 6137/6137 [==============================] - 497s 81ms/step - loss: 0.6933 - accuracy: 0.5046 - val_loss: 0.6931 - val_accuracy: 0.5079
# Epoch 5/1000
# 6137/6137 [==============================] - 490s 80ms/step - loss: 0.6933 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5083
# Epoch 6/1000
# 6137/6137 [==============================] - 489s 80ms/step - loss: 0.6933 - accuracy: 0.5058 - val_loss: 0.6930 - val_accuracy: 0.5086
# Epoch 7/1000
# 6137/6137 [==============================] - 484s 79ms/step - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6930 - val_accuracy: 0.5088
# Epoch 8/1000
# 6137/6137 [==============================] - 479s 78ms/step - loss: 0.6933 - accuracy: 0.5062 - val_loss: 0.6930 - val_accuracy: 0.5089
# Epoch 9/1000
# 6137/6137 [==============================] - 489s 80ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6930 - val_accuracy: 0.5089
# Epoch 10/1000
# 6137/6137 [==============================] - 712s 116ms/step - loss: 0.6933 - accuracy: 0.5059 - val_loss: 0.6930 - val_accuracy: 0.5089
# Epoch 11/1000
# 6137/6137 [==============================] - 569s 93ms/step - loss: 0.6933 - accuracy: 0.5046 - val_loss: 0.6930 - val_accuracy: 0.5090
# Epoch 12/1000
# 6137/6137 [==============================] - 482s 79ms/step - loss: 0.6932 - accuracy: 0.5059 - val_loss: 0.6930 - val_accuracy: 0.5084
# Epoch 13/1000
# 6137/6137 [==============================] - 483s 79ms/step - loss: 0.6933 - accuracy: 0.5063 - val_loss: 0.6930 - val_accuracy: 0.
saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 573s 93ms/step - loss: 0.6929 - accuracy: 0.5078 - val_loss: 0.6922 - val_accuracy: 0.5072
# Epoch 10/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5078
# Epoch 10: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 575s 94ms/step - loss: 0.6929 - accuracy: 0.5078 - val_loss: 0.6922 - val_accuracy: 0.5075
# Epoch 11/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5092
# Epoch 11: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 573s 94ms/step - loss: 0.6929 - accuracy: 0.5092 - val_loss: 0.6922 - val_accuracy: 0.5075
# Epoch 12/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5084
# Epoch 12: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 574s 94ms/step - loss: 0.6928 - accuracy: 0.5084 - val_loss: 0.6922 - val_accuracy: 0.5074
# Epoch 13/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5075
# Epoch 13: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 576s 94ms/step - loss: 0.6929 - accuracy: 0.5075 - val_loss: 0.6922 - val_accuracy: 0.5078
# Epoch 14/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5078
# Epoch 14: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 571s 93ms/step - loss: 0.6929 - accuracy: 0.5078 - val_loss: 0.6922 - val_accuracy: 0.5083
# Epoch 15/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5084
# Epoch 15: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 573s 93ms/step - loss: 0.6928 - accuracy: 0.5084 - val_loss: 0.6922 - val_accuracy: 0.5081
# Epoch 16/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5091
# Epoch 16: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 574s 94ms/step - loss: 0.6928 - accuracy: 0.5091 - val_loss: 0.6922 - val_accuracy: 0.5085
# Epoch 17/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5076
# Epoch 17: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 572s 93ms/step - loss: 0.6928 - accuracy: 0.5076 - val_loss: 0.6922 - val_accuracy: 0.5089
# Epoch 18/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5086
# Epoch 18: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 572s 93ms/step - loss: 0.6929 - accuracy: 0.5086 - val_loss: 0.6922 - val_accuracy: 0.5091
# Epoch 19/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5068
# Epoch 19: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 573s 93ms/step - loss: 0.6928 - accuracy: 0.5068 - val_loss: 0.6922 - val_accuracy: 0.5090
# Epoch 20/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5076
# Epoch 20: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 575s 94ms/step - loss: 0.6928 - accuracy: 0.5076 - val_loss: 0.6922 - val_accuracy: 0.5092
# Epoch 21/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5090
# Epoch 21: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight14.h5
# 6129/6129 [==============================] - 575s 94ms/step - loss: 0.6927 - accuracy: 0.5090 - val_loss: 0.6922 - val_accuracy: 0.5100
# Epoch 22/1000
# 4381/6129 [====================>.........] - ETA: 2:32 - loss: 0.6929 - accuracy: 0.5069

# %% [markdown]
# # For each sector

# %%
sector = pd.read_csv('/home/RDC/yeungwin/H:/yeungwin/industry_all.csv')
sector_list = sector["TRBC Economic Sector Name"].unique()
sector_list = [x for x in sector_list if pd.notnull(x)]
print(sector_list)
# Out:
# ['Healthcare', 'Financials', 'Industrials', 'Consumer Cyclicals', 'Technology', 'Consumer Non-Cyclicals', 'Energy', 'Utilities', 'Real Estate', 'Basic Materials', 'Academic & Educational Services']

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = {}
hyperparameter_records = []



for sector in sector_list:
    accuracy_results[sector] = {}  # Create a sub-dictionary for each sector
    for i in range(5):
        # read the data
        path = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
        train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
        train = train[train['sector']==sector]
        test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()
        test = test[test['sector']==sector]
        
        train.columns = label
        test.columns = label

        train_label = train.iloc[:, timesteps]
        train_data = train.iloc[:, :timesteps]
        test_label = test.iloc[:,timesteps]
        test_data = test.iloc[:, :timesteps]


         # reshape input
        #  data: (samples, timesteps, features)
        x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
        x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
        # label: (samples, target)
        y_train = np.array(train_label).reshape((len(train_label), num_classes))
        y_test = np.array(test_label).reshape((len(test_label), num_classes))

        print(x_train.shape)
        print(y_train.shape)
        print(x_test.shape)
        print(y_test.shape)

        print("-------------------------------------------------------------------------------------------------------")
        print("Training the model for Training Set " +sector+ str(i) + " from " +
        datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        print("-------------------------------------------------------------------------------------------------------")

        if i==0:
            directory_path ='lstm'+sector
            tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
                objective='val_accuracy',#overwrite=True
                max_trials=30, directory=directory_path, seed=111)
            tuner.search(x_train,y_train, epochs =3,validation_split=0.2)

            # save the best model
            hypermodel = MyHyperModel() # the same model but save training to different path
            best_hp = tuner.get_best_hyperparameters()[0]
            best_model = hypermodel.build(best_hp)
            print(sector+" ")
            best_hp_values = tuner.get_best_hyperparameters()[0].get_config()["values"]
            print(best_hp_values)
            early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                        patience = 10)
            result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])
            hyperparameter_records.append({
            "sector": sector,
            "hyperparameters": best_hp_values
        })

        else:
            load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight_'+sector+'.h5'
            print('Model restore from ' + load_path)
            cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                     save_weights_only=True,
                                                     verbose=1)
            early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                        patience = 10)

            result = best_model.fit(
                x_train, 
                y_train, 
                epochs = 1000, 
                validation_split=0.2,
                verbose =1,
                callbacks=[cp_callback, early_stop]        
            ) 


        save_path ='/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight_'+sector+".h5"
        best_model.save_weights(save_path)
        print("Model saved to " + save_path)
        print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))

        ##make prediction
        pred_ff_test = best_model.predict(x_test)
        pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
        output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                        'Date': test['target_date'], 'Sector': test['sector'], })
        accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
        print('Overall Accuracy for test set:'+ str(accuracy))
        accuracy_results[sector][i] = accuracy

        output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_pred/lstm_'+sector + '_prediction_period_'+str(i)+'.csv')
        print('Prediction for period ' +sector + str(i) + ' successfully saved.')
        
accuracy_df = pd.DataFrame(accuracy_results)
hyperparameter_df = pd.DataFrame(hyperparameter_records)

# %%
print(accuracy_df)

# %%
print(hyperparameter_df)
