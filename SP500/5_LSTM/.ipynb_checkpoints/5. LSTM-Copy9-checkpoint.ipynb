# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import datetime

import keras
from keras.models import Sequential
from keras.layers import Dense, InputLayer, LSTM, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
import keras_tuner
from keras import regularizers

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self,hp):
        model = Sequential()
        model.add(InputLayer(input_shape=(240,1 )))
        hp_units = hp.Choice('units', values=[32,64,128])
        hp_lr = hp.Choice('learning_rate', values=[1e-6,1e-7,1e-8])
        hp_regulariers = hp.Choice('regularies', values = ['l1','l2', 'None'])
        if hp_regulariers == 'l1':
            regularizers = keras.regularizers.L1(hp_lr)
        elif hp_regulariers == 'l2':
            regularizers = keras.regularizers.L2(hp_lr)
        elif hp_regulariers == 'None':
            regularizers = None
        
        model.add(LSTM(units=hp_units,kernel_regularizer=regularizers,name='dense_0'))
        model.add(Dropout(0.5))
        model.add(Dense(1, activation='sigmoid'))
        
        hp_optimizer = hp.Choice('optimizer', values=['sgd', 'rmsprop', 'adam',"adamax"])
        if hp_optimizer == 'sgd':
            optimizer = keras.optimizers.SGD(learning_rate=hp_lr)
        elif hp_optimizer == 'rmsprop':
            optimizer = keras.optimizers.RMSprop(learning_rate=hp_lr)
        elif hp_optimizer == 'adam':
            optimizer = keras.optimizers.Adam(learning_rate=hp_lr)
        elif hp_optimizer == 'adamax':
            optimizer = keras.optimizers.Adamax(learning_rate=hp_lr)
        else:
            raise ValueError("Invalid optimizer choice")

        model.compile(
            optimizer = optimizer
            ,loss=keras.losses.BinaryCrossentropy()
            , metrics=['accuracy'])
        return model


    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size=hp.Choice("batch_size", [16,32,64,128]),
                **kwargs,
            )

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = []


for i in range(3,5):
    # read the data
    path  = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
    train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
    test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()

    train.columns = label
    test.columns = label

    train_label = train.iloc[:, timesteps]
    train_data = train.iloc[:, :timesteps]
    test_label = test.iloc[:,timesteps]
    test_data = test.iloc[:, :timesteps]
    
    
     # reshape input
    #  data: (samples, timesteps, features)
    x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
    x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
    # label: (samples, target)
    y_train = np.array(train_label).reshape((len(train_label), num_classes))
    y_test = np.array(test_label).reshape((len(test_label), num_classes))
        
    print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)
    
    print("-------------------------------------------------------------------------------------------------------")
    print("Training the model for Training Set " + str(i) + " from " +
    datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
    print("-------------------------------------------------------------------------------------------------------")
        
    if i ==0:   
        tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy',# overwrite=True,
            max_trials=15, directory='lstm9', seed=12345)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience =10)
        tuner.search(x_train,y_train, epochs =100, validation_split=0.2, callbacks=[early_stop])

        # save the best model
        hypermodel = MyHyperModel()
        best_hp = tuner.get_best_hyperparameters()[0]
        best_model = hypermodel.build(best_hp)

        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
        result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])
        print(tuner.get_best_hyperparameters()[0].get_config()["values"])

    else: 
        load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5'
        print('Model restore from ' + load_path)
        

        
        tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy',# overwrite=True,
            max_trials=10, directory='lstm9', seed=12345)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience =3, restore_best_weights=False)
        tuner.search(x_train,y_train, epochs =100, validation_split=0.2, callbacks=[early_stop])

        # save the best model
        hypermodel = MyHyperModel()
        best_model = hypermodel.build(tuner.get_best_hyperparameters()[0])
        
        cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                 save_weights_only=True,
                                                 verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                    patience = 10)
        result = best_model.fit(
            x_train, 
            y_train, 
            epochs = 1000, 
            validation_split=0.2,
            verbose =1,
            callbacks=[cp_callback, early_stop]        
        ) 
            
    model_path ="/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5"    
    best_model.save_weights(model_path)
    print("Model saved to " + model_path)
    print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        
    ##make prediction
    pred_ff_test = best_model.predict(x_test)
    #pred = pred_ff_test.tolist()
    pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
    output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                    'Date': test['target_date'], 'Sector': test['sector'], })
    accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
    print('Overall Accuracy for test set:'+ str(accuracy))
    output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/pred9/lstm_prediction_period_'+str(i)+'.csv')
    print('Prediction for period ' + str(i) + ' successfully saved.')
# Out:
# (245140, 240, 1)
# (245140, 1)
# (119243, 240, 1)
# (119243, 1)
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 3 from 2024-03-26 10:08:54
# -------------------------------------------------------------------------------------------------------
# Model restore from /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# Reloading Tuner from lstm9/untitled_project/tuner0.json
# Epoch 1/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.4957
# Epoch 1: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] - 368s 60ms/step - loss: 0.6960 - accuracy: 0.4957 - val_loss: 0.6957 - val_accuracy: 0.4961
# Epoch 2/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6958 - accuracy: 0.4952
# Epoch 2: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] - 370s 60ms/step - loss: 0.6958 - accuracy: 0.4952 - val_loss: 0.6955 - val_accuracy: 0.4951
# Epoch 3/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6956 - accuracy: 0.4945
# Epoch 3: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] - 368s 60ms/step - loss: 0.6956 - accuracy: 0.4945 - val_loss: 0.6953 - val_accuracy: 0.4947
# Epoch 4/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.4959
# Epoch 4: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] - 368s 60ms/step - loss: 0.6955 - accuracy: 0.4959 - val_loss: 0.6952 - val_accuracy: 0.4947
# Epoch 5/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.4954
# Epoch 5: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] - 365s 59ms/step - loss: 0.6953 - accuracy: 0.4954 - val_loss: 0.6950 - val_accuracy: 0.4951
# Epoch 6/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.4957
# Epoch 6: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] - 366s 60ms/step - loss: 0.6953 - accuracy: 0.4957 - val_loss: 0.6949 - val_accuracy: 0.4946
# Epoch 7/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6951 - accuracy: 0.4971
# Epoch 7: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] - 369s 60ms/step - loss: 0.6951 - accuracy: 0.4971 - val_loss: 0.6948 - val_accuracy: 0.4943
# Epoch 8/1000
# 6129/6129 [==============================] - ETA: 0s - loss: 0.6949 - accuracy: 0.4965
# Epoch 8: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6129/6129 [==============================] -
[============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.5061
# Epoch 187: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 381s 62ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6928 - val_accuracy: 0.5053
# Epoch 188/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5062
# Epoch 188: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 380s 62ms/step - loss: 0.6933 - accuracy: 0.5062 - val_loss: 0.6928 - val_accuracy: 0.5054
# Epoch 189/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5043
# Epoch 189: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 374s 61ms/step - loss: 0.6934 - accuracy: 0.5043 - val_loss: 0.6928 - val_accuracy: 0.5055
# Epoch 190/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5047
# Epoch 190: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 376s 61ms/step - loss: 0.6932 - accuracy: 0.5047 - val_loss: 0.6928 - val_accuracy: 0.5054
# Epoch 191/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5057
# Epoch 191: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 381s 62ms/step - loss: 0.6932 - accuracy: 0.5057 - val_loss: 0.6928 - val_accuracy: 0.5054
# Epoch 192/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5062
# Epoch 192: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 389s 64ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6928 - val_accuracy: 0.5054
# Epoch 193/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5074
# Epoch 193: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 381s 62ms/step - loss: 0.6932 - accuracy: 0.5074 - val_loss: 0.6928 - val_accuracy: 0.5057
# Epoch 194/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5068
# Epoch 194: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 382s 63ms/step - loss: 0.6931 - accuracy: 0.5068 - val_loss: 0.6928 - val_accuracy: 0.5055
# Epoch 195/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5081
# Epoch 195: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 383s 63ms/step - loss: 0.6930 - accuracy: 0.5081 - val_loss: 0.6928 - val_accuracy: 0.5058
# Epoch 196/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5064
# Epoch 196: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 385s 63ms/step - loss: 0.6932 - accuracy: 0.5064 - val_loss: 0.6928 - val_accuracy: 0.5058
# Epoch 197/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5085
# Epoch 197: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 387s 63ms/step - loss: 0.6932 - accuracy: 0.5085 - val_loss: 0.6928 - val_accuracy: 0.5058
# Epoch 198/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5074
# Epoch 198: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 382s 62ms/step - loss: 0.6932 - accuracy: 0.5074 - val_loss: 0.6928 - val_accuracy: 0.5060
# Epoch 199/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5062
# Epoch 199: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 381s 62ms/step - loss: 0.6933 - accuracy: 0.5062 - val_loss: 0.6928 - val_accuracy: 0.5060
# Epoch 200/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5060
# Epoch 200: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 381s 62ms/step - loss: 0.6933 - accuracy: 0.5060 - val_loss: 0.6928 - val_accuracy: 0.5060
# Epoch 201/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5062
# Epoch 201: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 383s 63ms/step - loss: 0.6933 - accuracy: 0.5062 - val_loss: 0.6928 - val_accuracy: 0.5061
# Epoch 202/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5061
# Epoch 202: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 382s 62ms/step - loss: 0.6932 - accuracy: 0.5061 - val_loss: 0.6928 - val_accuracy: 0.5060
# Epoch 203/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5055
# Epoch 203: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 384s 63ms/step - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6928 - val_accuracy: 0.5064
# Epoch 204/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5064
# Epoch 204: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 384s 63ms/step - loss: 0.6932 - accuracy: 0.5064 - val_loss: 0.6928 - val_accuracy: 0.5061
# Epoch 205/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5071
# Epoch 205: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 383s 63ms/step - loss: 0.6932 - accuracy: 0.5071 - val_loss: 0.6928 - val_accuracy: 0.5063
# Epoch 206/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5061
# Epoch 206: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 388s 63ms/step - loss: 0.6932 - accuracy: 0.5061 - val_loss: 0.6928 - val_accuracy: 0.5066
# Epoch 207/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5071
# Epoch 207: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 379s 62ms/step - loss: 0.6932 - accuracy: 0.5071 - val_loss: 0.6928 - val_accuracy: 0.5065
# Epoch 208/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5081
# Epoch 208: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 386s 63ms/step - loss: 0.6932 - accuracy: 0.5081 - val_loss: 0.6928 - val_accuracy: 0.5063
# Epoch 209/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5071
# Epoch 209: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# 6110/6110 [==============================] - 386s 63ms/step - loss: 0.6931 - accuracy: 0.5071 - val_loss: 0.6928 - val_accuracy: 0.5063
# Model saved to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight9.h5
# Training end: 2024-03-28 12:34:17
# 3729/3729 [==============================] - 83s 22ms/step
# Overall Accuracy for test set:0.5048648648648648
# Prediction for period 4 successfully saved.
