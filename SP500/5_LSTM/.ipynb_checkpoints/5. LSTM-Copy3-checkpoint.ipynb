# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import datetime

import keras
from keras.models import Sequential
from keras.layers import Dense, InputLayer, LSTM, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
import keras_tuner
from keras import regularizers
# Out:
# 2024-02-20 21:09:16.448374: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-20 21:09:16.450902: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-20 21:09:16.494334: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-20 21:09:16.494364: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-20 21:09:16.494388: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-20 21:09:16.503347: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-20 21:09:16.504018: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-20 21:09:17.287135: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # 240 days data

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self,hp):
        model = Sequential()
        model.add(InputLayer(input_shape=(240,1 )))
        hp_units = hp.Choice('units', values=[32,64,128])
        hp_lr = hp.Choice('learning_rate', values=[1e-5, 1e-6,1e-7,1e-8])
        hp_regulariers = hp.Choice('regularies', values = ['l1','l2', 'None'])
        if hp_regulariers == 'l1':
            regularizers = keras.regularizers.L1(hp_lr)
        elif hp_regulariers == 'l2':
            regularizers = keras.regularizers.L2(hp_lr)
        elif hp_regulariers == 'None':
            regularizers = None
        
        model.add(LSTM(units=hp_units,kernel_regularizer=regularizers,name='dense_0'))
        model.add(Dropout(0.5))
        model.add(Dense(1, activation='sigmoid'))
        
        hp_optimizer = hp.Choice('optimizer', values=['sgd', 'rmsprop', 'adam',"adamax"])
        if hp_optimizer == 'sgd':
            optimizer = keras.optimizers.SGD(learning_rate=hp_lr)
        elif hp_optimizer == 'rmsprop':
            optimizer = keras.optimizers.RMSprop(learning_rate=hp_lr)
        elif hp_optimizer == 'adam':
            optimizer = keras.optimizers.Adam(learning_rate=hp_lr)
        elif hp_optimizer == 'adamax':
            optimizer = keras.optimizers.Adamax(learning_rate=hp_lr)
        else:
            raise ValueError("Invalid optimizer choice")

        model.compile(
            optimizer = optimizer
            ,loss=keras.losses.BinaryCrossentropy()
            , metrics=['accuracy'])
        return model


    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size=hp.Choice("batch_size", [16,32,64,128]),
                **kwargs,
            )

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = []


for i in range(3,5):
    # read the data
    path  = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
    train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
    test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()

    train.columns = label
    test.columns = label

    train_label = train.iloc[:, timesteps]
    train_data = train.iloc[:, :timesteps]
    test_label = test.iloc[:,timesteps]
    test_data = test.iloc[:, :timesteps]
    
    
     # reshape input
    #  data: (samples, timesteps, features)
    x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
    x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
    # label: (samples, target)
    y_train = np.array(train_label).reshape((len(train_label), num_classes))
    y_test = np.array(test_label).reshape((len(test_label), num_classes))
        
    print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)
    
    print("-------------------------------------------------------------------------------------------------------")
    print("Training the model for Training Set " + str(i) + " from " +
    datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
    print("-------------------------------------------------------------------------------------------------------")
        
    if i ==0:   
        tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy',# overwrite=True,
            max_trials=50, directory='lstm3', seed=80)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
        tuner.search(x_train,y_train, epochs =1000, validation_split=0.2, callbacks=[early_stop])

        # save the best model
        hypermodel = MyHyperModel()
        best_hp = tuner.get_best_hyperparameters()[0]
        best_model = hypermodel.build(best_hp)

        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
        result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])
        print(tuner.get_best_hyperparameters()[0].get_config()["values"])

    else: 
        tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy',# overwrite=True,
            max_trials=60, directory='lstm3', seed=80)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10, restore_best_weights=False)
        tuner.search(x_train,y_train, epochs =1000, validation_split=0.2, callbacks=[early_stop])

        load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5'
        print('Model restore from ' + load_path)
        cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                 save_weights_only=True,
                                                 verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                    patience = 10, restore_best_weights=False)

        result = best_model.fit(
            x_train, 
            y_train, 
            epochs = 1000, 
            validation_split=0.2,
            verbose =1,
            callbacks=[cp_callback, early_stop]        
        ) 
            
    model_path ="/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5"    
    best_model.save_weights(model_path)
    print("Model saved to " + model_path)
    print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        
    ##make prediction
    pred_ff_test = best_model.predict(x_test)
    #pred = pred_ff_test.tolist()
    pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
    output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                    'Date': test['target_date'], 'Sector': test['sector'], })
    accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
    print('Overall Accuracy for test set:'+ str(accuracy))
    output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/pred3/lstm_prediction_period_'+str(i)+'.csv')
    print('Prediction for period ' + str(i) + ' successfully saved.')
# Out:
# Trial 50 Complete [11h 56m 01s]
# val_accuracy: 0.5122115015983582
#
# Best val_accuracy So Far: 0.5131077766418457
# Total elapsed time: 22d 05h 46m 25s
# Epoch 1/1000
# 6137/6137 [==============================] - 678s 110ms/step - loss: 0.6932 - accuracy: 0.5039 - val_loss: 0.6930 - val_accuracy: 0.5107
# Epoch 2/1000
# 6137/6137 [==============================] - 685s 112ms/step - loss: 0.6932 - accuracy: 0.5060 - val_loss: 0.6930 - val_accuracy: 0.5115
# Epoch 3/1000
# 6137/6137 [==============================] - 677s 110ms/step - loss: 0.6932 - accuracy: 0.5057 - val_loss: 0.6930 - val_accuracy: 0.5112
# Epoch 4/1000
# 6137/6137 [==============================] - 689s 112ms/step - loss: 0.6932 - accuracy: 0.5069 - val_loss: 0.6930 - val_accuracy: 0.5108
# Epoch 5/1000
# 6137/6137 [==============================] - 686s 112ms/step - loss: 0.6931 - accuracy: 0.5076 - val_loss: 0.6930 - val_accuracy: 0.5111
# Epoch 6/1000
# 6137/6137 [==============================] - 686s 112ms/step - loss: 0.6931 - accuracy: 0.5067 - val_loss: 0.6930 - val_accuracy: 0.5109
# Epoch 7/1000
# 6137/6137 [==============================] - 686s 112ms/step - loss: 0.6931 - accuracy: 0.5070 - val_loss: 0.6930 - val_accuracy: 0.5107
# Epoch 8/1000
# 6137/6137 [==============================] - 669s 109ms/step - loss: 0.6930 - accuracy: 0.5075 - val_loss: 0.6930 - val_accuracy: 0.5111
# Epoch 9/1000
# 6137/6137 [==============================] - 689s 112ms/step - loss: 0.6930 - accuracy: 0.5074 - val_loss: 0.6930 - val_accuracy: 0.5105
# Epoch 10/1000
# 6137/6137 [==============================] - 693s 113ms/step - loss: 0.6931 - accuracy: 0.5063 - val_loss: 0.6930 - val_accuracy: 0.5105
# Epoch
1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5063
# Epoch 12: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 708s 116ms/step - loss: 0.6921 - accuracy: 0.5063 - val_loss: 0.6964 - val_accuracy: 0.5052
# Epoch 13/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5050
# Epoch 13: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 703s 115ms/step - loss: 0.6924 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.5054
# Epoch 14/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5062
# Epoch 14: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 686s 112ms/step - loss: 0.6920 - accuracy: 0.5062 - val_loss: 0.6953 - val_accuracy: 0.5051
# Epoch 15/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5066
# Epoch 15: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 655s 107ms/step - loss: 0.6920 - accuracy: 0.5066 - val_loss: 0.6959 - val_accuracy: 0.5047
# Epoch 16/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5061
# Epoch 16: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 653s 107ms/step - loss: 0.6919 - accuracy: 0.5061 - val_loss: 0.6950 - val_accuracy: 0.5050
# Epoch 17/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5070
# Epoch 17: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 653s 107ms/step - loss: 0.6926 - accuracy: 0.5070 - val_loss: 0.6950 - val_accuracy: 0.5051
# Epoch 18/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5062
# Epoch 18: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 660s 108ms/step - loss: 0.6921 - accuracy: 0.5062 - val_loss: 0.6948 - val_accuracy: 0.5057
# Epoch 19/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5061
# Epoch 19: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 658s 108ms/step - loss: 0.6919 - accuracy: 0.5061 - val_loss: 0.6956 - val_accuracy: 0.5056
# Epoch 20/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5056
# Epoch 20: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 664s 109ms/step - loss: 0.6921 - accuracy: 0.5056 - val_loss: 0.6952 - val_accuracy: 0.5055
# Epoch 21/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5068
# Epoch 21: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 712s 117ms/step - loss: 0.6919 - accuracy: 0.5068 - val_loss: 0.6952 - val_accuracy: 0.5055
# Epoch 22/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5061
# Epoch 22: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 720s 118ms/step - loss: 0.6919 - accuracy: 0.5061 - val_loss: 0.6953 - val_accuracy: 0.5058
# Epoch 23/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5050
# Epoch 23: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# 6110/6110 [==============================] - 673s 110ms/step - loss: 0.6920 - accuracy: 0.5050 - val_loss: 0.6954 - val_accuracy: 0.5062
# Model saved to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight3.h5
# Training end: 2024-03-04 09:37:51
# 3729/3729 [==============================] - 131s 35ms/step
# Overall Accuracy for test set:0.5076052796983029
# Prediction for period 4 successfully saved.

# %% [markdown]
# # For each sector

# %%
sector = pd.read_csv('/home/RDC/yeungwin/H:/yeungwin/industry_all.csv')
sector_list = sector["TRBC Economic Sector Name"].unique()
sector_list = [x for x in sector_list if pd.notnull(x)]
print(sector_list)
# Out:
# ['Healthcare', 'Financials', 'Industrials', 'Consumer Cyclicals', 'Technology', 'Consumer Non-Cyclicals', 'Energy', 'Utilities', 'Real Estate', 'Basic Materials', 'Academic & Educational Services']

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = {}
hyperparameter_records = []



for sector in sector_list:
    accuracy_results[sector] = {}  # Create a sub-dictionary for each sector
    for i in range(5):
        # read the data
        path = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
        train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
        train = train[train['sector']==sector]
        test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()
        test = test[test['sector']==sector]
        
        train.columns = label
        test.columns = label

        train_label = train.iloc[:, timesteps]
        train_data = train.iloc[:, :timesteps]
        test_label = test.iloc[:,timesteps]
        test_data = test.iloc[:, :timesteps]


         # reshape input
        #  data: (samples, timesteps, features)
        x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
        x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
        # label: (samples, target)
        y_train = np.array(train_label).reshape((len(train_label), num_classes))
        y_test = np.array(test_label).reshape((len(test_label), num_classes))

        print(x_train.shape)
        print(y_train.shape)
        print(x_test.shape)
        print(y_test.shape)

        print("-------------------------------------------------------------------------------------------------------")
        print("Training the model for Training Set " +sector+ str(i) + " from " +
        datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        print("-------------------------------------------------------------------------------------------------------")

        if i==0:
            directory_path ='lstm'+sector
            tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
                objective='val_accuracy',#overwrite=True
                max_trials=30, directory=directory_path, seed=111)
            tuner.search(x_train,y_train, epochs =3,validation_split=0.2)

            # save the best model
            hypermodel = MyHyperModel() # the same model but save training to different path
            best_hp = tuner.get_best_hyperparameters()[0]
            best_model = hypermodel.build(best_hp)
            print(sector+" ")
            best_hp_values = tuner.get_best_hyperparameters()[0].get_config()["values"]
            print(best_hp_values)
            early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                        patience = 10)
            result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])
            hyperparameter_records.append({
            "sector": sector,
            "hyperparameters": best_hp_values
        })

        else:
            load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight_'+sector+'.h5'
            print('Model restore from ' + load_path)
            cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                     save_weights_only=True,
                                                     verbose=1)
            early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                        patience = 10)

            result = best_model.fit(
                x_train, 
                y_train, 
                epochs = 1000, 
                validation_split=0.2,
                verbose =1,
                callbacks=[cp_callback, early_stop]        
            ) 


        save_path ='/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight_'+sector+".h5"
        best_model.save_weights(save_path)
        print("Model saved to " + save_path)
        print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))

        ##make prediction
        pred_ff_test = best_model.predict(x_test)
        pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
        output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                        'Date': test['target_date'], 'Sector': test['sector'], })
        accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
        print('Overall Accuracy for test set:'+ str(accuracy))
        accuracy_results[sector][i] = accuracy

        output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_pred/lstm_'+sector + '_prediction_period_'+str(i)+'.csv')
        print('Prediction for period ' +sector + str(i) + ' successfully saved.')
        
accuracy_df = pd.DataFrame(accuracy_results)
hyperparameter_df = pd.DataFrame(hyperparameter_records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      11 accuracy_results = {}
#      12 hyperparameter_records = []
# ---> 16 for sector in sector_list:
#      17     accuracy_results[sector] = {}  # Create a sub-dictionary for each sector
#      18     for i in range(5):
#      19         # read the data
#
# NameError: name 'sector_list' is not defined

# %%
print(accuracy_df)

# %%
print(hyperparameter_df)
