# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import datetime

import keras
from keras.models import Sequential
from keras.layers import Dense, InputLayer, LSTM, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
import keras_tuner
from keras import regularizers
# Out:
# 2024-02-20 21:08:58.302361: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-20 21:08:58.304967: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-20 21:08:58.348960: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-20 21:08:58.348978: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-20 21:08:58.349002: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-20 21:08:58.358375: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-20 21:08:58.359045: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-20 21:08:59.121450: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # 240 days data

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self,hp):
        model = Sequential()
        model.add(InputLayer(input_shape=(240,1 )))
        hp_units = hp.Choice('units', values=[32,64,128])
        hp_lr = hp.Choice('learning_rate', values=[1e-6,1e-7,1e-8])
        hp_regulariers = hp.Choice('regularies', values = ['l1','l2', 'None'])
        if hp_regulariers == 'l1':
            regularizers = keras.regularizers.L1(hp_lr)
        elif hp_regulariers == 'l2':
            regularizers = keras.regularizers.L2(hp_lr)
        elif hp_regulariers == 'None':
            regularizers = None
        
        model.add(LSTM(units=hp_units,kernel_regularizer=regularizers,name='dense_0'))
        model.add(Dropout(hp.Choice('dropout_rate',values =[0.5])))
        model.add(Dense(1, activation='sigmoid'))
        
        hp_optimizer = hp.Choice('optimizer', values=['sgd', 'rmsprop', 'adam',"adamax"])
        if hp_optimizer == 'sgd':
            optimizer = keras.optimizers.SGD(learning_rate=hp_lr)
        elif hp_optimizer == 'rmsprop':
            optimizer = keras.optimizers.RMSprop(learning_rate=hp_lr)
        elif hp_optimizer == 'adam':
            optimizer = keras.optimizers.Adam(learning_rate=hp_lr)
        elif hp_optimizer == 'adamax':
            optimizer = keras.optimizers.Adamax(learning_rate=hp_lr)
        else:
            raise ValueError("Invalid optimizer choice")

        model.compile(
            optimizer = optimizer
            ,loss=keras.losses.BinaryCrossentropy()
            , metrics=['accuracy'])
        return model


    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size=hp.Choice("batch_size", [16,32,64,128]),
                **kwargs,
            )

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = []


for i in range(5):
    # read the data
    path  = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
    train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
    test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()

    train.columns = label
    test.columns = label

    train_label = train.iloc[:, timesteps]
    train_data = train.iloc[:, :timesteps]
    test_label = test.iloc[:,timesteps]
    test_data = test.iloc[:, :timesteps]
    
    
     # reshape input
    #  data: (samples, timesteps, features)
    x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
    x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
    # label: (samples, target)
    y_train = np.array(train_label).reshape((len(train_label), num_classes))
    y_test = np.array(test_label).reshape((len(test_label), num_classes))
        
    print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)
    
    print("-------------------------------------------------------------------------------------------------------")
    print("Training the model for Training Set " + str(i) + " from " +
    datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
    print("-------------------------------------------------------------------------------------------------------")
        
    if i ==0:   
        tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
            objective='val_accuracy', #overwrite=True,
            max_trials=30, directory='lstm1', seed=111)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
        tuner.search(x_train,y_train, epochs =100, validation_split=0.2, callbacks=[early_stop])

        # save the best model
        hypermodel = MyHyperModel()
        best_hp = tuner.get_best_hyperparameters()[0]
        best_model = hypermodel.build(best_hp)

        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
        result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])
        print(tuner.get_best_hyperparameters()[0].get_config()["values"])

    else: 
        load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5'
        print('Model restore from ' + load_path)
        cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                 save_weights_only=True,
                                                 verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 10)

        result = best_model.fit(
            x_train, 
            y_train, 
            epochs = 1000, 
            validation_split=0.2,
            verbose =1,
            callbacks=[cp_callback, early_stop]        
        ) 
            
    model_path ="/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5"    
    best_model.save_weights(model_path)
    print("Model saved to " + model_path)
    print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        
    ##make prediction
    pred_ff_test = best_model.predict(x_test)
    #pred = pred_ff_test.tolist()
    pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
    output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                    'Date': test['target_date'], 'Sector': test['sector'], })
    accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
    print('Overall Accuracy for test set:'+ str(accuracy))
    output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_prediction/lstm_prediction_period_'+str(i)+'.csv')
    print('Prediction for period ' + str(i) + ' successfully saved.')
# Out:
# Trial 30 Complete [1d 01h 22m 34s]
# val_accuracy: 0.5135355591773987
#
# Best val_accuracy So Far: 0.513800323009491
# Total elapsed time: 16d 00h 06m 13s
# Epoch 1/1000
# 6137/6137 [==============================] - 403s 65ms/step - loss: 0.6937 - accuracy: 0.4993 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 2/1000
# 6137/6137 [==============================] - 427s 70ms/step - loss: 0.6937 - accuracy: 0.5012 - val_loss: 0.6930 - val_accuracy: 0.5042
# Epoch 3/1000
# 6137/6137 [==============================] - 449s 73ms/step - loss: 0.6937 - accuracy: 0.5025 - val_loss: 0.6930 - val_accuracy: 0.5047
# Epoch 4/1000
# 6137/6137 [==============================] - 445s 73ms/step - loss: 0.6936 - accuracy: 0.5036 - val_loss: 0.6930 - val_accuracy: 0.5050
# Epoch 5/1000
# 6137/6137 [==============================] - 450s 73ms/step - loss: 0.6937 - accuracy: 0.5029 - val_loss: 0.6930 - val_accuracy: 0.5062
# Epoch 6/1000
# 6137/6137 [==============================] - 436s 71ms/step - loss: 0.6936 - accuracy: 0.5045 - val_loss: 0.6930 - val_accuracy: 0.5062
# Epoch 7/1000
# 6137/6137 [==============================] - 448s 73ms/step - loss: 0.6937 - accuracy: 0.5050 - val_loss: 0.6930 - val_accuracy: 0.5084
# Epoch
saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 819s 134ms/step - loss: 0.6932 - accuracy: 0.5063 - val_loss: 0.6927 - val_accuracy: 0.5047
# Epoch 72/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5053
# Epoch 72: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 836s 137ms/step - loss: 0.6932 - accuracy: 0.5053 - val_loss: 0.6927 - val_accuracy: 0.5051
# Epoch 73/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5061
# Epoch 73: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 821s 134ms/step - loss: 0.6932 - accuracy: 0.5061 - val_loss: 0.6927 - val_accuracy: 0.5049
# Epoch 74/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5057
# Epoch 74: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 787s 129ms/step - loss: 0.6932 - accuracy: 0.5057 - val_loss: 0.6927 - val_accuracy: 0.5050
# Epoch 75/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5071
# Epoch 75: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 798s 131ms/step - loss: 0.6932 - accuracy: 0.5071 - val_loss: 0.6927 - val_accuracy: 0.5049
# Epoch 76/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5059
# Epoch 76: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 782s 128ms/step - loss: 0.6933 - accuracy: 0.5059 - val_loss: 0.6927 - val_accuracy: 0.5048
# Epoch 77/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5059
# Epoch 77: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 781s 128ms/step - loss: 0.6932 - accuracy: 0.5059 - val_loss: 0.6927 - val_accuracy: 0.5051
# Epoch 78/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5038
# Epoch 78: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 788s 129ms/step - loss: 0.6933 - accuracy: 0.5038 - val_loss: 0.6927 - val_accuracy: 0.5053
# Epoch 79/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5048
# Epoch 79: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 782s 128ms/step - loss: 0.6933 - accuracy: 0.5048 - val_loss: 0.6927 - val_accuracy: 0.5053
# Epoch 80/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5070
# Epoch 80: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 783s 128ms/step - loss: 0.6933 - accuracy: 0.5070 - val_loss: 0.6927 - val_accuracy: 0.5052
# Epoch 81/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5062
# Epoch 81: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 797s 130ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6927 - val_accuracy: 0.5052
# Epoch 82/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5077
# Epoch 82: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 845s 138ms/step - loss: 0.6932 - accuracy: 0.5077 - val_loss: 0.6927 - val_accuracy: 0.5051
# Epoch 83/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5080
# Epoch 83: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 842s 138ms/step - loss: 0.6931 - accuracy: 0.5080 - val_loss: 0.6927 - val_accuracy: 0.5050
# Epoch 84/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5058
# Epoch 84: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 838s 137ms/step - loss: 0.6932 - accuracy: 0.5058 - val_loss: 0.6927 - val_accuracy: 0.5053
# Epoch 85/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5053
# Epoch 85: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 811s 133ms/step - loss: 0.6933 - accuracy: 0.5053 - val_loss: 0.6927 - val_accuracy: 0.5047
# Epoch 86/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5066
# Epoch 86: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 800s 131ms/step - loss: 0.6932 - accuracy: 0.5066 - val_loss: 0.6927 - val_accuracy: 0.5049
# Epoch 87/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5064
# Epoch 87: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# 6110/6110 [==============================] - 507s 83ms/step - loss: 0.6932 - accuracy: 0.5064 - val_loss: 0.6927 - val_accuracy: 0.5050
# Model saved to /home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight1.h5
# Training end: 2024-02-28 13:19:34
# 3729/3729 [==============================] - 65s 18ms/step
# Overall Accuracy for test set:0.5075633773308192
# Prediction for period 4 successfully saved.

# %% [markdown]
# # For each sector

# %%
sector = pd.read_csv('/home/RDC/yeungwin/H:/yeungwin/industry_all.csv')
sector_list = sector["TRBC Economic Sector Name"].unique()
sector_list = [x for x in sector_list if pd.notnull(x)]
print(sector_list)
# Out:
# ['Healthcare', 'Financials', 'Industrials', 'Consumer Cyclicals', 'Technology', 'Consumer Non-Cyclicals', 'Energy', 'Utilities', 'Real Estate', 'Basic Materials', 'Academic & Educational Services']

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = {}
hyperparameter_records = []



for sector in sector_list:
    accuracy_results[sector] = {}  # Create a sub-dictionary for each sector
    for i in range(5):
        # read the data
        path = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
        train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
        train = train[train['sector']==sector]
        test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()
        test = test[test['sector']==sector]
        
        train.columns = label
        test.columns = label

        train_label = train.iloc[:, timesteps]
        train_data = train.iloc[:, :timesteps]
        test_label = test.iloc[:,timesteps]
        test_data = test.iloc[:, :timesteps]


         # reshape input
        #  data: (samples, timesteps, features)
        x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
        x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
        # label: (samples, target)
        y_train = np.array(train_label).reshape((len(train_label), num_classes))
        y_test = np.array(test_label).reshape((len(test_label), num_classes))

        print(x_train.shape)
        print(y_train.shape)
        print(x_test.shape)
        print(y_test.shape)

        print("-------------------------------------------------------------------------------------------------------")
        print("Training the model for Training Set " +sector+ str(i) + " from " +
        datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        print("-------------------------------------------------------------------------------------------------------")

        if i==0:
            directory_path ='lstm'+sector
            tuner = keras_tuner.BayesianOptimization(MyHyperModel(),
                objective='val_accuracy',#overwrite=True
                max_trials=30, directory=directory_path, seed=111)
            tuner.search(x_train,y_train, epochs =3,validation_split=0.2)

            # save the best model
            hypermodel = MyHyperModel() # the same model but save training to different path
            best_hp = tuner.get_best_hyperparameters()[0]
            best_model = hypermodel.build(best_hp)
            print(sector+" ")
            best_hp_values = tuner.get_best_hyperparameters()[0].get_config()["values"]
            print(best_hp_values)
            early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                        patience = 10)
            result = best_model.fit(x_train,y_train, epochs=1000, validation_split =0.2, verbose =1, callbacks=[early_stop])
            hyperparameter_records.append({
            "sector": sector,
            "hyperparameters": best_hp_values
        })

        else:
            load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight_'+sector+'.h5'
            print('Model restore from ' + load_path)
            cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                     save_weights_only=True,
                                                     verbose=1)
            early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                        patience = 10)

            result = best_model.fit(
                x_train, 
                y_train, 
                epochs = 1000, 
                validation_split=0.2,
                verbose =1,
                callbacks=[cp_callback, early_stop]        
            ) 


        save_path ='/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_weight/lstm_weight_'+sector+".h5"
        best_model.save_weights(save_path)
        print("Model saved to " + save_path)
        print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))

        ##make prediction
        pred_ff_test = best_model.predict(x_test)
        pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
        output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                        'Date': test['target_date'], 'Sector': test['sector'], })
        accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
        print('Overall Accuracy for test set:'+ str(accuracy))
        accuracy_results[sector][i] = accuracy

        output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/5_LSTM/lstm_pred/lstm_'+sector + '_prediction_period_'+str(i)+'.csv')
        print('Prediction for period ' +sector + str(i) + ' successfully saved.')
        
accuracy_df = pd.DataFrame(accuracy_results)
hyperparameter_df = pd.DataFrame(hyperparameter_records)

# %%
print(accuracy_df)

# %%
print(hyperparameter_df)
