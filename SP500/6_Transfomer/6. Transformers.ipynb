# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import datetime

import keras
from keras.models import Sequential
from keras.layers import Dense,InputLayer, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score


import numpy as np
from scikeras.wrappers import KerasClassifier
import keras_tuner
from tensorflow.keras import layers
# Out:
# 2024-03-26 12:42:41.749812: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-26 12:42:42.991910: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 12:42:42.991963: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 12:42:42.996556: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-26 12:42:43.516397: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-26 12:42:48.616339: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend

# %% [markdown]
# # Global Model

# %%
# transformer model
n_timesteps, n_features = 240, 1
def transformer_encoder(inputs, head_size, num_heads, ff_dim,
                        dropout=0, attention_axes=None):
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
      key_dim=head_size, num_heads=num_heads, dropout=dropout,
      attention_axes=attention_axes
      )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

def build_transformer(head_size, 
                      num_heads,
                      ff_dim,
                      num_trans_blocks,
                      mlp_units, dropout, mlp_dropout, activation) -> tf.keras.Model:
    #n_timesteps, n_features, n_outputs = 240, 1, 1
    inputs = tf.keras.Input(shape=(n_timesteps, n_features))
    x = inputs 
    
    for _ in range(num_trans_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)
    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation=activation)(x)
        x = layers.Dropout(mlp_dropout)(x)

    outputs = layers.Dense(1, activation='sigmoid')(x)
    return tf.keras.Model(inputs, outputs)


def build_model(hp):
    head_size = hp.Choice("head_size",[32,64,128]) #embeding size for attention
    num_heads = hp.Choice("num_heads",[4,8,16])  #number of attention head
    ff_dim =  hp.Choice("ff_dim",[2,4,8,16,32])# hidden layer size in FNN insider transformer
    activation = hp.Choice("activation",["elu","relu","selu","tanh"])
    num_trans_blocks=  hp.Choice("num_trans_blocks",[2,4,8,16])
    #dropout = hp.Choice("drop_out",[0.3,0.5,0.7])
    #mlp_dropout= hp.Choice("mlp_dropout",[0.3,0.5,0.7])
    model = build_transformer(head_size, num_heads,ff_dim,num_trans_blocks,[256], 0.5, 0.5,activation)
    hp_lr = hp.Choice('learning_rate', values=[1e-6,1e-7,1e-8])
    hp_optimizer = hp.Choice('optimizer', values=['sgd', 'rmsprop', 'adam',"adamax"])
    if hp_optimizer == 'sgd':
        optimizer = keras.optimizers.SGD(learning_rate=hp_lr)
    elif hp_optimizer == 'rmsprop':
        optimizer = keras.optimizers.RMSprop(learning_rate=hp_lr)
    elif hp_optimizer == 'adam':
        optimizer = keras.optimizers.Adam(learning_rate=hp_lr)
    elif hp_optimizer == 'adamax':
        optimizer = keras.optimizers.Adamax(learning_rate=hp_lr)
    else:
        raise ValueError("Invalid optimizer choice")

    model.compile(optimizer = hp_optimizer,loss=keras.losses.BinaryCrossentropy(), metrics=['accuracy'])
    return model

# %%
timesteps = 240
num_input =1
num_classes=1
label = list(range(timesteps)) + ['target'] + ['ticker'] + ['target_date'] + ['sector']

training_data = []
training_label = []
testing_data =[]
testing_label =[]

accuracy_results = []

for i in range(5):
    # read the data
    path = '/home/RDC/yeungwin/H:/yeungwin/SP500/data/'
    train = pd.read_csv(path+'Set_' + str(i) + '_Train.csv', index_col=0).dropna()
    test = pd.read_csv(path+'Set_' + str(i) + '_Test.csv', index_col=0).dropna()

    train.columns = label
    test.columns = label

    train_label = train.iloc[:, timesteps]
    train_data = train.iloc[:, :timesteps]
    test_label = test.iloc[:,timesteps]
    test_data = test.iloc[:, :timesteps]
    
    
     # reshape input
    #  data: (samples, timesteps, features)
    x_train = np.array(train_data).reshape((len(train_data), timesteps, num_input), order = 'F')
    x_test = np.array(test_data).reshape((len(test_data), timesteps, num_input), order = 'F')
    # label: (samples, target)
    y_train = np.array(train_label).reshape((len(train_label), num_classes))
    y_test = np.array(test_label).reshape((len(test_label), num_classes))
        
    print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)
    
    print("-------------------------------------------------------------------------------------------------------")
    print("Training the model for Training Set " + str(i) + " from " +
    datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
    print("-------------------------------------------------------------------------------------------------------")
        
    if i==0:
        tuner = keras_tuner.BayesianOptimization(build_model,
            objective='val_accuracy', #overwrite=True,
            #hyperband_iterations = 3,max_epochs =10,
            max_trials=30, directory='transformer', seed=10)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience =10, restore_best_weights=False)
        tuner.search(x_train,y_train, epochs =1000,validation_split=0.2, callbacks=[early_stop])

        # save the best model
        #hypermodel =build_model
        best_hp = tuner.get_best_hyperparameters()[0]
        best_model = build_model(best_hp)
        print(tuner.get_best_hyperparameters()[0].get_config()["values"])

        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 10,restore_best_weights=False)
        result = best_model.fit(x_train,y_train, epochs=1000, batch_size=64,validation_split =0.2, verbose =1, callbacks=[early_stop])

        
    else:
        tuner = keras_tuner.BayesianOptimization(build_model,objective='val_accuracy', #overwrite=True,
            #hyperband_iterations = 3,max_epochs =10,
            max_trials=10, directory='transformer', seed=111)
        # save the best model
        best_hp = tuner.get_best_hyperparameters()[0]
        best_model = build_model(best_hp)
        load_path = '/home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight.h5'
        print('Model restore from ' + load_path)
        cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=load_path,
                                                 save_weights_only=True,
                                                 verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                    patience = 10, restore_best_weights=False)

        result = best_model.fit(
            x_train, 
            y_train, 
            epochs = 1000, 
            validation_split=0.2,
            verbose =1,
            callbacks=[cp_callback, early_stop]        
        ) 
        
    save_path = "/home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight.h5"
    best_model.save_weights(save_path)
    print("Model saved to " + save_path)
    print("Training end: " + datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S'))
        
    ##make prediction
    pred_ff_test = best_model.predict(x_test)
    #pred = pred_ff_test.tolist()
    pred = pred_ff_test.reshape((1, len(pred_ff_test))).tolist()[0]
    output_data = pd.DataFrame({'y_prob': pred, 'y_true': test['target'], 'Ticker': test['ticker'],
                                    'Date': test['target_date'], 'Sector': test['sector'], })
    accuracy = accuracy_score(np.round(output_data['y_prob']), output_data['y_true'])
    print('Overall Accuracy for test set:'+ str(accuracy))
    
    
    output_data.to_csv('/home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/tf_pred/tf_prediction_period_'+str(i)+'.csv')
    print('Prediction for period ' + str(i) + ' successfully saved.')
# Out:
# (244381, 240, 1)
# (244381, 1)
# (119325, 240, 1)
# (119325, 1)
# -------------------------------------------------------------------------------------------------------
# Training the model for Training Set 4 from 2024-02-09 14:28:33
# -------------------------------------------------------------------------------------------------------
# Reloading Tuner from transformer/untitled_project/tuner0.json
# Model restore from /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# Epoch 1/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.7107 - accuracy: 0.5115
# Epoch 1: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 465s 76ms/step - loss: 0.7107 - accuracy: 0.5115 - val_loss: 0.6927 - val_accuracy: 0.5181
# Epoch 2/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6919 - accuracy: 0.5234
# Epoch 2: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 459s 75ms/step - loss: 0.6919 - accuracy: 0.5234 - val_loss: 0.6926 - val_accuracy: 0.5195
# Epoch 3/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6904 - accuracy: 0.5301
# Epoch 3: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 474s 78ms/step - loss: 0.6904 - accuracy: 0.5301 - val_loss: 0.6915 - val_accuracy: 0.5249
# Epoch 4/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.5356
# Epoch 4: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 477s 78ms/step - loss: 0.6888 - accuracy: 0.5356 - val_loss: 0.6903 - val_accuracy: 0.5301
# Epoch 5/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5468
# Epoch 5: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 486s 79ms/step - loss: 0.6858 - accuracy: 0.5468 - val_loss: 0.6879 - val_accuracy: 0.5375
# Epoch 6/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6836 - accuracy: 0.5525
# Epoch 6: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6836 - accuracy: 0.5525 - val_loss: 0.6855 - val_accuracy: 0.5443
# Epoch 7/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6797 - accuracy: 0.5618
# Epoch 7: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 480s 79ms/step - loss: 0.6797 - accuracy: 0.5618 - val_loss: 0.6826 - val_accuracy: 0.5571
# Epoch 8/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6767 - accuracy: 0.5681
# Epoch 8: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 481s 79ms/step - loss: 0.6767 - accuracy: 0.5681 - val_loss: 0.6806 - val_accuracy: 0.5578
# Epoch 9/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6730 - accuracy: 0.5763
# Epoch 9: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6730 - accuracy: 0.5763 - val_loss: 0.6782 - val_accuracy: 0.5643
# Epoch 10/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6701 - accuracy: 0.5797
# Epoch 10: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 479s 78ms/step - loss: 0.6701 - accuracy: 0.5798 - val_loss: 0.6762 - val_accuracy: 0.5673
# Epoch 11/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6659 - accuracy: 0.5882
# Epoch 11: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 476s 78ms/step - loss: 0.6659 - accuracy: 0.5882 - val_loss: 0.6735 - val_accuracy: 0.5725
# Epoch 12/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6629 - accuracy: 0.5934
# Epoch 12: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 472s 77ms/step - loss: 0.6629 - accuracy: 0.5934 - val_loss: 0.6732 - val_accuracy: 0.5707
# Epoch 13/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6606 - accuracy: 0.5966
# Epoch 13: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 473s 77ms/step - loss: 0.6606 - accuracy: 0.5966 - val_loss: 0.6706 - val_accuracy: 0.5825
# Epoch 14/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6579 - accuracy: 0.6014
# Epoch 14: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 477s 78ms/step - loss: 0.6579 - accuracy: 0.6014 - val_loss: 0.6702 - val_accuracy: 0.5779
# Epoch 15/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6557 - accuracy: 0.6046
# Epoch 15: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 478s 78ms/step - loss: 0.6557 - accuracy: 0.6046 - val_loss: 0.6681 - val_accuracy: 0.5810
# Epoch 16/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6527 - accuracy: 0.6093
# Epoch 16: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6527 - accuracy: 0.6093 - val_loss: 0.6679 - val_accuracy: 0.5804
# Epoch 17/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6513 - accuracy: 0.6103
# Epoch 17: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 483s 79ms/step - loss: 0.6513 - accuracy: 0.6103 - val_loss: 0.6669 - val_accuracy: 0.5839
# Epoch 18/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6490 - accuracy: 0.6150
# Epoch 18: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 481s 79ms/step - loss: 0.6490 - accuracy: 0.6150 - val_loss: 0.6643 - val_accuracy: 0.5882
# Epoch 19/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6471 - accuracy: 0.6173
# Epoch 19: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 483s 79ms/step - loss: 0.6471 - accuracy: 0.6173 - val_loss: 0.6638 - val_accuracy: 0.5896
# Epoch 20/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6447 - accuracy: 0.6215
# Epoch 20: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6447 - accuracy: 0.6215 - val_loss: 0.6638 - val_accuracy: 0.5891
# Epoch 21/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6427 - accuracy: 0.6237
# Epoch 21: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 481s 79ms/step - loss: 0.6427 - accuracy: 0.6237 - val_loss: 0.6629 - val_accuracy: 0.5916
# Epoch 22/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.6265
# Epoch 22: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 479s 78ms/step - loss: 0.6403 - accuracy: 0.6264 - val_loss: 0.6620 - val_accuracy: 0.5891
# Epoch 23/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6378 - accuracy: 0.6292
# Epoch 23: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 478s 78ms/step - loss: 0.6378 - accuracy: 0.6293 - val_loss: 0.6618 - val_accuracy: 0.5908
# Epoch 24/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6379 - accuracy: 0.6301
# Epoch 24: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 475s 78ms/step - loss: 0.6378 - accuracy: 0.6301 - val_loss: 0.6610 - val_accuracy: 0.5909
# Epoch 25/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6358 - accuracy: 0.6330
# Epoch 25: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 477s 78ms/step - loss: 0.6358 - accuracy: 0.6330 - val_loss: 0.6601 - val_accuracy: 0.5944
# Epoch 26/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6342 - accuracy: 0.6343
# Epoch 26: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 476s 78ms/step - loss: 0.6342 - accuracy: 0.6343 - val_loss: 0.6598 - val_accuracy: 0.5935
# Epoch 27/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6324 - accuracy: 0.6356
# Epoch 27: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 475s 78ms/step - loss: 0.6324 - accuracy: 0.6356 - val_loss: 0.6595 - val_accuracy: 0.5931
# Epoch 28/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6309 - accuracy: 0.6391
# Epoch 28: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 477s 78ms/step - loss: 0.6309 - accuracy: 0.6392 - val_loss: 0.6583 - val_accuracy: 0.5952
# Epoch 29/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6295 - accuracy: 0.6402
# Epoch 29: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 476s 78ms/step - loss: 0.6295 - accuracy: 0.6402 - val_loss: 0.6577 - val_accuracy: 0.5953
# Epoch 30/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6292 - accuracy: 0.6409
# Epoch 30: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 578s 95ms/step - loss: 0.6292 - accuracy: 0.6409 - val_loss: 0.6587 - val_accuracy: 0.5920
# Epoch 31/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.6439
# Epoch 31: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 617s 101ms/step - loss: 0.6265 - accuracy: 0.6439 - val_loss: 0.6582 - val_accuracy: 0.5933
# Epoch 32/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6260 - accuracy: 0.6446
# Epoch 32: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 619s 101ms/step - loss: 0.6260 - accuracy: 0.6446 - val_loss: 0.6575 - val_accuracy: 0.5949
# Epoch 33/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6248 - accuracy: 0.6460
# Epoch 33: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 650s 106ms/step - loss: 0.6248 - accuracy: 0.6460 - val_loss: 0.6573 - val_accuracy: 0.5956
# Epoch 34/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6239 - accuracy: 0.6460
# Epoch 34: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 478s 78ms/step - loss: 0.6239 - accuracy: 0.6460 - val_loss: 0.6579 - val_accuracy: 0.5945
# Epoch 35/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6236 - accuracy: 0.6469
# Epoch 35: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 473s 77ms/step - loss: 0.6236 - accuracy: 0.6469 - val_loss: 0.6567 - val_accuracy: 0.5971
# Epoch 36/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6219 - accuracy: 0.6500
# Epoch 36: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 473s 77ms/step - loss: 0.6219 - accuracy: 0.6500 - val_loss: 0.6560 - val_accuracy: 0.5981
# Epoch 37/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6203 - accuracy: 0.6504
# Epoch 37: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 475s 78ms/step - loss: 0.6203 - accuracy: 0.6504 - val_loss: 0.6556 - val_accuracy: 0.5991
# Epoch 38/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6189 - accuracy: 0.6513
# Epoch 38: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 478s 78ms/step - loss: 0.6189 - accuracy: 0.6513 - val_loss: 0.6555 - val_accuracy: 0.5983
# Epoch 39/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6186 - accuracy: 0.6526
# Epoch 39: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 475s 78ms/step - loss: 0.6186 - accuracy: 0.6527 - val_loss: 0.6553 - val_accuracy: 0.5998
# Epoch 40/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6170 - accuracy: 0.6538
# Epoch 40: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 478s 78ms/step - loss: 0.6170 - accuracy: 0.6538 - val_loss: 0.6552 - val_accuracy: 0.5982
# Epoch 41/1000
# 6110/6110 [==============================] - ETA: 0s - loss: 0.6163 - accuracy: 0.6552
# Epoch 41: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6163 - accuracy: 0.6552 - val_loss: 0.6558 - val_accuracy: 0.5957
# Epoch 42/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6149 - accuracy: 0.6550
# Epoch 42: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6149 - accuracy: 0.6550 - val_loss: 0.6545 - val_accuracy: 0.5978
# Epoch 43/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6146 - accuracy: 0.6563
# Epoch 43: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6146 - accuracy: 0.6563 - val_loss: 0.6548 - val_accuracy: 0.5978
# Epoch 44/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6128 - accuracy: 0.6585
# Epoch 44: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6128 - accuracy: 0.6585 - val_loss: 0.6544 - val_accuracy: 0.6016
# Epoch 45/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6132 - accuracy: 0.6592
# Epoch 45: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 479s 78ms/step - loss: 0.6132 - accuracy: 0.6592 - val_loss: 0.6541 - val_accuracy: 0.6013
# Epoch 46/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6124 - accuracy: 0.6583
# Epoch 46: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 482s 79ms/step - loss: 0.6124 - accuracy: 0.6583 - val_loss: 0.6552 - val_accuracy: 0.5997
# Epoch 47/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6110 - accuracy: 0.6592
# Epoch 47: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 479s 78ms/step - loss: 0.6110 - accuracy: 0.6592 - val_loss: 0.6536 - val_accuracy: 0.6012
# Epoch 48/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6116 - accuracy: 0.6597
# Epoch 48: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 477s 78ms/step - loss: 0.6116 - accuracy: 0.6597 - val_loss: 0.6543 - val_accuracy: 0.5993
# Epoch 49/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6108 - accuracy: 0.6621
# Epoch 49: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 481s 79ms/step - loss: 0.6108 - accuracy: 0.6621 - val_loss: 0.6537 - val_accuracy: 0.6012
# Epoch 50/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6076 - accuracy: 0.6646
# Epoch 50: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 481s 79ms/step - loss: 0.6076 - accuracy: 0.6646 - val_loss: 0.6537 - val_accuracy: 0.6002
# Epoch 51/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6062 - accuracy: 0.6659
# Epoch 51: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 474s 78ms/step - loss: 0.6062 - accuracy: 0.6659 - val_loss: 0.6531 - val_accuracy: 0.6001
# Epoch 52/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6060 - accuracy: 0.6662
# Epoch 52: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 472s 77ms/step - loss: 0.6060 - accuracy: 0.6662 - val_loss: 0.6531 - val_accuracy: 0.6030
# Epoch 53/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6069 - accuracy: 0.6648
# Epoch 53: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 456s 75ms/step - loss: 0.6069 - accuracy: 0.6648 - val_loss: 0.6530 - val_accuracy: 0.6011
# Epoch 54/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6057 - accuracy: 0.6669
# Epoch 54: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 462s 76ms/step - loss: 0.6057 - accuracy: 0.6668 - val_loss: 0.6531 - val_accuracy: 0.6002
# Epoch 55/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6059 - accuracy: 0.6649
# Epoch 55: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 475s 78ms/step - loss: 0.6059 - accuracy: 0.6649 - val_loss: 0.6539 - val_accuracy: 0.5992
# Epoch 56/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6056 - accuracy: 0.6655
# Epoch 56: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 480s 79ms/step - loss: 0.6056 - accuracy: 0.6655 - val_loss: 0.6529 - val_accuracy: 0.6008
# Epoch 57/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6044 - accuracy: 0.6677
# Epoch 57: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 478s 78ms/step - loss: 0.6044 - accuracy: 0.6677 - val_loss: 0.6534 - val_accuracy: 0.5998
# Epoch 58/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6041 - accuracy: 0.6691
# Epoch 58: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 478s 78ms/step - loss: 0.6041 - accuracy: 0.6691 - val_loss: 0.6534 - val_accuracy: 0.6001
# Epoch 59/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6034 - accuracy: 0.6684
# Epoch 59: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 477s 78ms/step - loss: 0.6034 - accuracy: 0.6684 - val_loss: 0.6540 - val_accuracy: 0.6012
# Epoch 60/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6029 - accuracy: 0.6695
# Epoch 60: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 479s 78ms/step - loss: 0.6030 - accuracy: 0.6695 - val_loss: 0.6528 - val_accuracy: 0.6000
# Epoch 61/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6016 - accuracy: 0.6716
# Epoch 61: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 477s 78ms/step - loss: 0.6016 - accuracy: 0.6717 - val_loss: 0.6532 - val_accuracy: 0.6001
# Epoch 62/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6010 - accuracy: 0.6703
# Epoch 62: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 476s 78ms/step - loss: 0.6010 - accuracy: 0.6703 - val_loss: 0.6540 - val_accuracy: 0.5974
# Epoch 63/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6002 - accuracy: 0.6714
# Epoch 63: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 474s 78ms/step - loss: 0.6002 - accuracy: 0.6714 - val_loss: 0.6535 - val_accuracy: 0.5986
# Epoch 64/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.6007 - accuracy: 0.6714
# Epoch 64: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 474s 78ms/step - loss: 0.6007 - accuracy: 0.6714 - val_loss: 0.6535 - val_accuracy: 0.5951
# Epoch 65/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.5995 - accuracy: 0.6718
# Epoch 65: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 476s 78ms/step - loss: 0.5995 - accuracy: 0.6718 - val_loss: 0.6538 - val_accuracy: 0.6013
# Epoch 66/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.5984 - accuracy: 0.6727
# Epoch 66: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 475s 78ms/step - loss: 0.5983 - accuracy: 0.6727 - val_loss: 0.6535 - val_accuracy: 0.5989
# Epoch 67/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.5991 - accuracy: 0.6733
# Epoch 67: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 474s 78ms/step - loss: 0.5991 - accuracy: 0.6733 - val_loss: 0.6541 - val_accuracy: 0.5985
# Epoch 68/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.5995 - accuracy: 0.6726
# Epoch 68: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 475s 78ms/step - loss: 0.5995 - accuracy: 0.6726 - val_loss: 0.6538 - val_accuracy: 0.5994
# Epoch 69/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.5978 - accuracy: 0.6750
# Epoch 69: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 472s 77ms/step - loss: 0.5978 - accuracy: 0.6750 - val_loss: 0.6536 - val_accuracy: 0.6000
# Epoch 70/1000
# 6109/6110 [============================>.] - ETA: 0s - loss: 0.5973 - accuracy: 0.6744
# Epoch 70: saving model to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# 6110/6110 [==============================] - 469s 77ms/step - loss: 0.5973 - accuracy: 0.6744 - val_loss: 0.6531 - val_accuracy: 0.6021
# Model saved to /home/RDC/yeungwin/H:/yeungwin/SP500/6_Transfomer/transformer_model_weight/tf_weight3.h5
# Training end: 2024-02-09 23:53:58
# 3729/3729 [==============================] - 95s 25ms/step
# Overall Accuracy for test set:0.502828409805154
# Prediction for period 4 successfully saved.

# %%
tuner = keras_tuner.BayesianOptimization(build_model,
    objective='val_accuracy',
    max_trials=10, directory='transformer3', seed=10)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience =3 )

# save the best model
print(tuner.get_best_hyperparameters()[0].get_config()["values"])
# Out:
# Reloading Tuner from transformer3/untitled_project/tuner0.json
# {'head_size': 32, 'num_heads': 4, 'ff_dim': 8, 'activation': 'tanh', 'num_trans_blocks': 4, 'learning_rate': 1e-07, 'optimizer': 'rmsprop'}
